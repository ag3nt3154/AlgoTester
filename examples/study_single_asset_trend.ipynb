# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Trend following strategy
#
# We want to investigate the performance of a trend following strategy which operates on the same principle as Time Series Momentum (https://doi.org/10.1016/j.jfineco.2011.11.003).
#
# ## Theory
#
# - Future returns are auto-correlated with past returns
# - Trend following is a long-short strategy across time. We buy the asset during periods of positive momentum and sell it during periods of negative momentum to harvest trend premium.
# - Market risk is "hedged" across time since we are long and short the same asset, albeit at different times. The same is true for any risks that are do not vary with time.
#     - We do hold risk since we have a net exposure to the asset at a given time. However, hedging out this risk turns this into a cross-sectional momentum strategy?
#     - Not sure if this is the right way to think about it.
# - We assume that the trend premium varies with time, and is particularly sensitive to the frequency / lookback period of the trend.
#     - We should look to optimize the lookback period (and other parameters).
# - Assume that the strategies rebalances once per month (21 days).
#
# ## Tests
# - Different ways of measuring trend / momentum
#     - lagged returns
#     - simple moving average
#     - exponential moving average
#     - breakout
#     - moving average crossovers
# - Parameters
# - Allocation across multiple assets

# %% [markdown]
# ## General Libraries

# %%
import pandas as pd
import numpy as np
from utils.backtester import BackTester
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from utils.data_fetcher import YahooDataFetcher
import datetime

# %% [markdown]
# ## Update Price Data
#
# We start by evaluating 3 asset classes
# - SPY -> equity
# - TLT -> bond
# - GLD -> gold

# %%
# Current date
current_date = datetime.datetime.now().date()
current_date = current_date.strftime("%Y%m%d")
print(current_date)

# Fetch daily price data from Yahoo Finance
fetcher = YahooDataFetcher()
ticker_list = [
    "SPY",
    "GLD", 
    "TLT",
]
fetcher.load_price_data(tickers=ticker_list)
price_data = {}
for ticker in ticker_list:
    df = pd.read_pickle(f'data/raw/price/{ticker}_{current_date}.pkl') 
    price_data[ticker] = df
# Out:
# INFO:utils.data_fetcher:Fetching data for SPY with yfinance
# 20250315
# INFO:utils.data_fetcher:Fetching data for GLD with yfinance
# INFO:utils.data_fetcher:Fetching data for TLT with yfinance

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Use SPY for testing
ticker = "SPY"
df = price_data[ticker].copy()

# Calculate daily returns and monthly returns
df['return'] = df['close'].pct_change()
df['monthly_return'] = df['close'].rolling(window=21).apply(lambda x: (x[-1] - x[0]) / x[0])

# Histogram of returns
plt.figure(figsize=(10, 6))
plt.hist(df['monthly_return'], bins=100, color='red', alpha=0.5)
plt.hist(df['return'], bins=100, color='blue', alpha=0.5)
plt.title('Distribution of Daily and Monthly Returns')
plt.xlabel('Return')
plt.ylabel('Frequency')
plt.legend(['Daily', 'Monthly'])
plt.show()

# Cumulative returns
plt.figure(figsize=(10, 6))
plt.plot(df.index, (1 + df['return']).cumprod())
plt.title('Cumulative Returns')
plt.xlabel('Date')
plt.ylabel('Cumulative Return')
plt.show()

# %% [markdown]
# ### Price movement

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
df_spy = df.copy()


def get_linear_regression(X, y, verbose=True, x_label='X', y_label='y'):
    # Ensure X is a 2D array for sklearn
    X = np.array(X).reshape(-1, 1)
    y = np.array(y)
    
    # Fit the linear regression model
    model = LinearRegression()
    model.fit(X, y)
    
    # Predict y values
    y_pred = model.predict(X)
    
    # Calculate R^2
    r2 = r2_score(y, y_pred)
    
    if verbose:
        # Plot the scatter plot and the regression line
        plt.scatter(X, y, color='blue', label='Data points')
        plt.plot(X, y_pred, color='red', label='Linear regression')
        plt.xlabel(x_label)
        plt.ylabel(y_label)
        plt.title('Linear Regression Fit')
        plt.legend()
        
        # Display the parameters and R^2
        print(f"Slope (Coefficient):    {model.coef_[0]:.4f}")
        print(f"Intercept:              {model.intercept_:.4f}")
        print(f"R^2:                    {r2:.4f}")
        
        plt.show()

    return model.coef_[0], model.intercept_, r2

period = 252

# plot past n - day trend
for i in range(df_spy.shape[0]):
    if i < period:
        continue
    if i % period != 0:
        continue
    close_arr = df_spy[i-period:i]['close'].to_numpy()
    close_arr = np.log(close_arr)
    # get linear regression
    slope, intercept, r2 = get_linear_regression(range(period), close_arr, x_label='t', y_label='return')


    if i == 20 * period:
        break
# Out:
# Slope (Coefficient):    0.0003
# Intercept:              3.7854
# R^2:                    0.7488
# Slope (Coefficient):    0.0000
# Intercept:              3.8290
# R^2:                    0.0013
# Slope (Coefficient):    0.0011
# Intercept:              3.8758
# R^2:                    0.9703
# Slope (Coefficient):    0.0007
# Intercept:              4.1338
# R^2:                    0.7409
# Slope (Coefficient):    0.0010
# Intercept:              4.3518
# R^2:                    0.7960
# Slope (Coefficient):    0.0004
# Intercept:              4.6495
# R^2:                    0.2413
# Slope (Coefficient):    0.0004
# Intercept:              4.8436
# R^2:                    0.5040
# Slope (Coefficient):    -0.0002
# Intercept:              4.9881
# R^2:                    0.1725
# Slope (Coefficient):    -0.0006
# Intercept:              4.8514
# R^2:                    0.4440
# Slope (Coefficient):    -0.0012
# Intercept:              4.7348
# R^2:                    0.6915
# Slope (Coefficient):    0.0012
# Intercept:              4.4383
# R^2:                    0.9234
# Slope (Coefficient):    0.0002
# Intercept:              4.7113
# R^2:                    0.2071
# Slope (Coefficient):    0.0003
# Intercept:              4.7650
# R^2:                    0.5289
# Slope (Coefficient):    0.0005
# Intercept:              4.8241
# R^2:                    0.6331
# Slope (Coefficient):    -0.0000
# Intercept:              4.9940
# R^2:                    0.0007
# Slope (Coefficient):    -0.0023
# Intercept:              5.0409
# R^2:                    0.7784
# Slope (Coefficient):    0.0017
# Intercept:              4.3562
# R^2:                    0.8886
# Slope (Coefficient):    0.0004
# Intercept:              4.6912
# R^2:                    0.3227
# Slope (Coefficient):    -0.0003
# Intercept:              4.8873
# R^2:                    0.2546
# Slope (Coefficient):    0.0003
# Intercept:              4.8987
# R^2:                    0.4510

# %% [markdown]
# ### Distribution of trend

# %%
from scipy.stats import norm
r2_arr = []
slope_arr = []
mean_ret_arr = []

period = 252



def find_k_for_percentile(arr, n):
    """
    Fits a normal distribution to the array and finds the value k such that
    the nth percentile of values fall outside of [-k, k] under the fitted distribution.

    Parameters:
        arr (numpy array): The input array.
        n (float): The percentile (0 < n < 100).

    Returns:
        k (float): The value such that the nth percentile of values fall outside [-k, k].
    """
    if n <= 0 or n >= 100:
        raise ValueError("n must be between 0 and 100 (exclusive).")
    
    # Fit a normal distribution to the data
    mu, sigma = np.mean(arr), np.std(arr)
    
    # Calculate the value k such that the nth percentile falls outside [-k, k]
    # This is equivalent to finding the (100 - n)/2 percentile of the normal distribution
    percentile = (100 - n) / 100  # Convert to a fraction
    k = norm.ppf(percentile, loc=mu, scale=sigma)
    return k
    

# plot past n - day trend
for i in range(df_spy.shape[0]):
    if i < period:
        continue
    if i % 21 != 0:
        continue
    close_arr = df_spy[i-period:i]['close'].to_numpy()
    log_close_arr = np.log(close_arr)
    # get linear regression
    slope, intercept, r2 = get_linear_regression(range(period), log_close_arr, x_label='t', y_label='return', verbose=False)
    r2_arr.append(r2)
    slope_arr.append(slope)
    mean_ret_arr.append((close_arr[-1] / close_arr[0])**(1/period) - 1)

    

plt.hist(r2_arr, bins=50)
plt.xlabel('r2')
plt.ylabel('frequency')
plt.show()

plt.scatter(slope_arr, r2_arr)
plt.xlabel('slope')
plt.ylabel('r2')
plt.show()

plt.scatter(mean_ret_arr, r2_arr)
plt.xlabel('mean return')
plt.ylabel('r2')
plt.show()

# %% [markdown]
# ## Lagged Returns
#
# Let's see how the future returns are correlated with lagged returns.

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

def get_lagged_returns(df, lag_period):
    df = df.copy()
    df['forward_monthly_returns'] = df['close'].rolling(21).apply(lambda x: (x[-1] - x[0]) / x[0]).shift(-21)
    df['lagged_returns'] = df['close'].rolling(lag_period).apply(lambda x: (x[-1] - x[0]) / x[0])
    df = df[['forward_monthly_returns', 'lagged_returns']]
    df.dropna(inplace=True)
    return df

def get_linear_regression(X, y, verbose=True, x_label='X', y_label='y'):
    # Ensure X is a 2D array for sklearn
    X = np.array(X).reshape(-1, 1)
    y = np.array(y)
    
    # Fit the linear regression model
    model = LinearRegression()
    model.fit(X, y)
    
    # Predict y values
    y_pred = model.predict(X)
    
    # Calculate R^2
    r2 = r2_score(y, y_pred)
    
    if verbose:
        # Plot the scatter plot and the regression line
        plt.scatter(X, y, color='blue', label='Data points')
        plt.plot(X, y_pred, color='red', label='Linear regression')
        plt.xlabel(x_label)
        plt.ylabel(y_label)
        plt.title('Linear Regression Fit')
        plt.legend()
        
        # Display the parameters and R^2
        print(f"Slope (Coefficient):    {model.coef_[0]:.4f}")
        print(f"Intercept:              {model.intercept_:.4f}")
        print(f"R^2:                    {r2:.4f}")
        
        plt.show()

    return model.coef_[0], model.intercept_, r2

# Look at correlation with 1 month lagged returns
df_plot = get_lagged_returns(df, 21)

get_linear_regression(df_plot['lagged_returns'], df_plot['forward_monthly_returns'], verbose=True, x_label='Lagged Returns', y_label='Forward Returns')
# Out:
# Slope (Coefficient):    -0.0705
# Intercept:              0.0079
# R^2:                    0.0050
# (-0.0704917107886966, 0.007930223584386489, 0.004954379850881652)

# %% [markdown]
# ### Linear Regression for different lookback periods

# %%
X = range(5, 500, 5)
y = []

for x in tqdm(X):
    df_plot = get_lagged_returns(df, x)
    _, _, r2 = get_linear_regression(
        df_plot['lagged_returns'],
        df_plot['forward_monthly_returns'],
        verbose=False,
    )
    y.append(r2)

plt.plot(X, y)
plt.xlabel('Lookback Period')
plt.ylabel('R2')
plt.show()
# Out:
#   0%|          | 0/99 [00:00<?, ?it/s]

# %% [markdown]
# Conlusion:
# - No good lookback period for linear regression

# %% [markdown]
# ### Binary Decision
#
# Next we look at setting the problem up as a binary decision:
# - if lagged_returns > 0: long
# - if lagged_returns < 0: short
#
# We are looking for the highest difference in returns between the two.

# %%
def get_lagged_returns_diff(df, period):
    df = df.copy()
    df = get_lagged_returns(df, period)
    pos_returns = df.loc[df['lagged_returns'] >= 0]['forward_monthly_returns'].to_list()
    neg_returns = df.loc[df['lagged_returns'] < 0]['forward_monthly_returns'].to_list()
    return pos_returns, neg_returns

# Plot mean difference between forward returns from positive and negative lagged returns
X = range(5, 500, 5)
y_returns = []


for period in tqdm(X):
    pos_returns, neg_returns = get_lagged_returns_diff(df, period)
    y_returns.append((pos_returns, neg_returns))

y_mean = [np.mean(pos_returns) - np.mean(neg_returns) for pos_returns, neg_returns in y_returns]
plt.plot(X, y_mean, label='mean difference')
plt.plot(X, [np.mean(y[0]) for y in y_returns], label='pos returns')
plt.plot(X, [np.mean(y[1]) for y in y_returns], label='neg returns')
plt.legend()
plt.xlabel('period')
plt.ylabel('Returns')
plt.show()

y_std = [np.std(pos_returns) - np.std(neg_returns) for pos_returns, neg_returns in y_returns]
plt.plot(X, y_std, label='std difference')
plt.plot(X, [np.std(y[0]) for y in y_returns], label='pos returns')
plt.plot(X, [np.std(y[1]) for y in y_returns], label='neg returns')
plt.legend()
plt.xlabel('period')
plt.ylabel('Volatility of forward monthly returns')
plt.show()
# Out:
#   0%|          | 0/99 [00:00<?, ?it/s]

# %% [markdown]
# Analysis:
# - Mean forward monthly returns are always positive for all lookback periods. We are not directly making returns by shorting when the lagged returns are negative.
# - Mean forward monthly returns when lagged returns are positive remain approximately constant.
# - Mean forward monthly returns when lagged returns are negative decrease as the lookback period increases.
# - The mean difference increases as the lookback period increases, reach a maxima at ~ 250 days.
# - Volatility of forward monthly returns show a consistent difference. When lagged returns are negative, the volatility of forward monthly returns is higher.
#     - Returns from the strategy may come from volatility reasons, i.e. we avoid highly volatile periods by reducing position size when lagged returns are negative.
#     - This suggests that me should reduce position size, rather than short the asset when lagged returns are negative.
#     - This also suggests that the strategy may be long volatility. We may out-perform the index when volatility rises by avoiding highly volatile periods.

# %% [markdown]
# ### Visualization of lagged returns

# %%
df_plot = df.copy()
df_plot['lagged_returns'] = df_plot['close'].pct_change(periods=252)
df_plot['lagged_returns'] = df_plot['lagged_returns'].apply(lambda x: 1 if x > 0 else 0)
# print(df_plot)

fig, ax1 = plt.subplots(figsize=(20, 8))
ax1.plot(df_plot.index, df_plot['close'])
ax1.set_xlabel('Date')
ax1.set_ylabel('Close Price')
ax1.grid(True)
ax1.set_yscale('log')
ax2 = ax1.twinx()
ax2.plot(df_plot.index, df_plot['lagged_returns'], color='red', alpha=0.5)
ax2.set_ylabel('Lagged Returns')
plt.show()

# %% [markdown]
# ### Performance across asset history
#
# Look at how the forward monthly returns vary across the history of the asset.

# %%
# Define lookback periods
X = range(5, 500, 2)
df_best_lookback = pd.DataFrame()

# Create figure and primary axis
fig, ax1 = plt.subplots(figsize=(20, 8))

# Use Viridis colormap for the rolling_proxy_return plots
colors = plt.cm.viridis(np.linspace(0, 1, len(X)))

# Plot rolling_proxy_return for each lookback period
for period, color in zip(tqdm(X), colors):
    df_plot = get_lagged_returns(df, period)
    df_plot['proxy_return'] = (df_plot['forward_monthly_returns'] * (df_plot['lagged_returns'].apply(lambda x: 1 if x >= 0 else -1)) + 1) ** (1 / 21)
    df_plot['rolling_proxy_return'] = df_plot['proxy_return'].rolling(252).apply(lambda x: np.prod(x))
    ax1.plot(df_plot.index, df_plot['rolling_proxy_return'], label=f'lookback={period}', color=color)

    df_best_lookback[period] = df_plot['rolling_proxy_return']
    df_best_lookback = df_best_lookback.copy()

# Set limits and labels for the primary y-axis
ax1.set_xlim(df_plot.index[2520], df_plot.index[-1])
ax1.set_xlabel('Date')
ax1.set_ylabel('Return over past 252 days', color='black')
ax1.tick_params(axis='y', labelcolor='black')
# ax1.legend(loc='upper left')

# Create a secondary y-axis for the optimal lookback
ax2 = ax1.twinx()

# Plot optimal lookback on the secondary y-axis
df_best_lookback.dropna(inplace=True)
df_best_lookback['optimal_lookback'] = df_best_lookback.idxmax(axis=1)
ax2.plot(df_best_lookback.index, df_best_lookback['optimal_lookback'], label='Optimal Lookback', color='red', linestyle='--')

# Set limits and labels for the secondary y-axis
ax2.set_ylabel('Optimal Lookback', color='red')
ax2.tick_params(axis='y', labelcolor='red')
ax2.legend(loc='upper right')

# Title and show
plt.title('Rolling Proxy Return and Optimal Lookback')
plt.show()
# Out:
#   0%|          | 0/248 [00:00<?, ?it/s]

# %%
# Create figure and primary axis
fig, ax1 = plt.subplots(figsize=(20, 8))
ax1.plot(df_best_lookback.index, df_best_lookback['optimal_lookback'], label='opt_lookback')
ax1.set_xlim(df_best_lookback.index[0], df_best_lookback.index[-1])
ax1.legend(loc='upper left')
ax1.set_ylabel('Optimal Lookback / days')
ax2 = ax1.twinx()
ax2.plot(df.index, df['close'], label='Close Price', color='red')
ax2.set_yscale('log')
ax2.legend(loc='lower left')
ax2.set_ylabel('Close Price (log scale)')
plt.xlabel('Date')
plt.show()

# %% [markdown]
# Analysis:
# - Optimal lookback period varies across history.
# - Optimal lookback period remains stable for some time (sometimes up to a year)
# - Optimal lookback period is higher (500 days) and more stable when market is less volatile.
# - Optimal lookback period is lower and changes more quickly when market is more volatile (e.g. 2008, 2020)
# - There is a possibility of predicting or following the optimal lookback period.

# %% [markdown]
# ### Comparison to VIX

# %%
fetcher = YahooDataFetcher()
ticker = "^VIX"
fetcher.load_price_data(tickers=[ticker])
df_vix = pd.read_pickle(f'data/raw/price/{ticker}_{current_date}.pkl') 

   
# Create figure and primary axis
fig, ax1 = plt.subplots(figsize=(20, 8))
ax1.plot(df_best_lookback.index, df_best_lookback['optimal_lookback'], label='opt_lookback')
ax1.set_xlim(df_best_lookback.index[0], df_best_lookback.index[-1])
ax1.legend(loc='upper left')
ax1.set_ylabel('Optimal Lookback / days')
ax2 = ax1.twinx()
ax2.plot(df_vix.index, df_vix['close'], label='Close Price', color='red')
ax2.set_yscale('log')
ax2.legend(loc='lower left')
ax2.set_ylabel('VIX close')
plt.xlabel('Date')
plt.show()

df_plot = pd.merge(df_best_lookback, df_vix, left_index=True, right_index=True)
df_plot = df_plot[['optimal_lookback', 'close']]

slope, intercept, r2 = get_linear_regression(X=df_plot['close'], y=df_plot['optimal_lookback'], verbose=True, x_label='VIX close', y_label='optimal_lookback')
# Out:
# INFO:utils.data_fetcher:Fetching data for ^VIX with yfinance
# INFO:utils.data_fetcher:Moved ^VIX_20250311.pkl to archive
# Slope (Coefficient):    -2.3052
# Intercept:              218.9272
# R^2:                    0.0252

# %% [markdown]
# ## Compare VIX to realised volatility

# %%
df_spy = df[['return']].copy()
df_spy['vol'] = df_spy['return'].rolling(21).std()
# df_spy['vol'] = df_spy['vol'].shift(-21)
df_plot = pd.merge(df_spy, df_vix, left_index=True, right_index=True)
df_plot.dropna(inplace=True)

get_linear_regression(X=df_plot['close'], y=df_plot['vol'], verbose=True, x_label='Close', y_label='Vol')
# Out:
# Slope (Coefficient):    0.0007
# Intercept:              -0.0032
# R^2:                    0.7606
# (0.0006769656394195203, -0.003197799253682628, 0.7606446195275689)

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 assert False
#
# AssertionError:

# %% [markdown]
# # END

# %% [markdown]
# # Buy-Hold Reference

# %%
from strategies.buy_hold import BuyHoldStrategy

def test_buy_hold(ticker, df, verbose=False):
    bt = BackTester({ticker: df})

    # Example 1: Buy and Hold
    bt.add_strategy(BuyHoldStrategy, tickers=[ticker], price_data={ticker: df})
    results = bt.backtest()
    if verbose:
        print("Buy and Hold Results:", {k: v for k, v in results.items() if k != 'returns'})
        bt.plot_results()
    return results['returns']

# %% [markdown]
# # Moving Average Crossover

# %% [markdown]
# ## Reference: long_window=252, short_window=21

# %%
from strategies.trend_following import MovingAverageCrossoverStrategy

def test_moving_average_crossover(ticker, df, long_window, short_window, verbose=False):
    tl = [ticker]
    pda = {ticker: df}
    bt = BackTester(pda)
    bt.add_strategy(MovingAverageCrossoverStrategy, tickers=tl, price_data=pda, short_window=short_window, long_window=long_window, rebalance_period=21)
    results = bt.backtest()
    if verbose:
        print(f"Results for asset [{ticker}]: ")
        for key in results:
            if key == 'returns': continue
            print(f"{key}: {results[key]}")
        bt.plot_results()
    return results['returns']

# %% [markdown]
# ## Oracle: Optimal long and short windows

# %%
import optuna
from optuna.samplers import TPESampler



def optimize_params(ticker, df, n_trials=100):
    def objective(trial):
        long_window = trial.suggest_int("long_window", 50, 500)
        short_window = trial.suggest_int("short_window", 5, 252)

        if long_window < short_window:
            return -1
        
        tl = [ticker]
        pda = {ticker: df}
        bt = BackTester(pda)
        bt.add_strategy(MovingAverageCrossoverStrategy, tickers=tl, price_data=pda, short_window=short_window, long_window=long_window, rebalance_period=21)
        results = bt.backtest()
        
        return results['sharpe']
        
    study = optuna.create_study(direction="maximize", sampler=TPESampler(seed=42))
    study.optimize(objective, n_trials=n_trials, show_progress_bar=True)

    return study.best_params


def test_oracle_MA(ticker, df, n_trials=100, verbose=False):
    best_params = optimize_params(ticker, df, n_trials)
    if verbose:
        print(f"Best params: {best_params}")
    results = test_moving_average_crossover(
        ticker=ticker,
        df=df,
        short_window=best_params['short_window'],
        long_window=best_params['long_window'],
        verbose=verbose,
    )
    return results

# %% [markdown]
# # Prior Period Optimization

# %%
from sklearn.model_selection import TimeSeriesSplit
# Initialize TimeSeriesSplit


def test_prior_period_opt(ticker, df, n_splits=5, n_trials=100, verbose=False):
    tscv = TimeSeriesSplit(n_splits=n_splits)
    rets = pd.DataFrame()
    # Perform cross-validation splits
    for train_index, test_index in tscv.split(df):
        train = df.iloc[train_index]
        test = df.iloc[test_index]
        if verbose:
            print("Training set size:", len(train), "Testing set size:", len(test))

        # Fit the model on the training set
        best_params = optimize_params(ticker, train, n_trials)

        results = test_moving_average_crossover(
            ticker, 
            test, 
            short_window=best_params['short_window'], 
            long_window=best_params['long_window'],
            verbose=verbose,
        )

        rets = pd.concat([rets, results], axis=0)

    return rets

# %% [markdown]
# # Comparison

# %% [markdown]
# ## SPY

# %%
n_trials = 100

returns_logs = dict()

ticker = "SPY"
df_data = price_data[ticker]
returns_logs['buy_hold'] = test_buy_hold(
    ticker=ticker,
    df=df_data,
    verbose=False,
)
returns_logs['ma_cross_reference'] = test_moving_average_crossover(
    ticker=ticker,
    df=df_data,
    short_window=21,
    long_window=252,
    verbose=False,
)
returns_logs['ma_cross_oracle'] = test_oracle_MA(
    ticker=ticker,
    df=df_data,
    n_trials=100,
    verbose=False,
)

for i in [5, 10]:
    returns_logs[f'ma_cross_prior_opt_{i}'] = test_prior_period_opt(
        ticker=ticker,
        df=df_data,
        n_splits=i,
        n_trials=50,
        verbose=False,
    )
# Out:
# [I 2025-03-02 20:22:13,875] A new study created in memory with name: no-name-6a0a57ae-db2a-44d8-b967-e23e1424a1de
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-03-02 20:22:13,883] Trial 0 finished with value: -1.0 and parameters: {'long_window': 218, 'short_window': 240}. Best is trial 0 with value: -1.0.
# [I 2025-03-02 20:22:17,616] Trial 1 finished with value: 0.7087372350647015 and parameters: {'long_window': 380, 'short_window': 153}. Best is trial 1 with value: 0.7087372350647015.
# [I 2025-03-02 20:22:21,411] Trial 2 finished with value: 0.6897631825645651 and parameters: {'long_window': 120, 'short_window': 43}. Best is trial 1 with value: 0.7087372350647015.
# [I 2025-03-02 20:22:21,414] Trial 3 finished with value: -1.0 and parameters: {'long_window': 76, 'short_window': 219}. Best is trial 1 with value: 0.7087372350647015.
# [I 2025-03-02 20:22:25,207] Trial 4 finished with value: 0.7405097468993455 and parameters: {'long_window': 321, 'short_window': 180}. Best is trial 4 with value: 0.7405097468993455.
# [I 2025-03-02 20:22:25,209] Trial 5 finished with value: -1.0 and parameters: {'long_window': 59, 'short_window': 245}. Best is trial 4 with value: 0.7405097468993455.
# [I 2025-03-02 20:22:28,953] Trial 6 finished with value: 0.673143445226723 and parameters: {'long_window': 425, 'short_window': 57}. Best is trial 4 with value: 0.7405097468993455.
# [I 2025-03-02 20:22:32,751] Trial 7 finished with value: 0.5410707188176564 and parameters: {'long_window': 132, 'short_window': 50}. Best is trial 4 with value: 0.7405097468993455.
# [I 2025-03-02 20:22:36,555] Trial 8 finished with value: 0.7182150626462066 and parameters: {'long_window': 187, 'short_window': 135}. Best is trial 4 with value: 0.7405097468993455.
# [I 2025-03-02 20:22:40,723] Trial 9 finished with value: 0.6678307415909847 and parameters: {'long_window': 244, 'short_window': 77}. Best is trial 4 with value: 0.7405097468993455.
# [I 2025-03-02 20:22:44,528] Trial 10 finished with value: 0.7317406580119289 and parameters: {'long_window': 335, 'short_window': 183}. Best is trial 4 with value: 0.7405097468993455.
# [I 2025-03-02 20:22:48,316] Trial 11 finished with value: 0.7469807476393641 and parameters: {'long_window': 317, 'short_window': 183}. Best is trial 11 with value: 0.7469807476393641.
# [I 2025-03-02 20:22:52,106] Trial 12 finished with value: 0.745042735612762 and parameters: {'long_window': 312, 'short_window': 186}. Best is trial 11 with value: 0.7469807476393641.
# [I 2025-03-02 20:22:55,873] Trial 13 finished with value: 0.7385798321443321 and parameters: {'long_window': 469, 'short_window': 102}. Best is trial 11 with value: 0.7469807476393641.
# [I 2025-03-02 20:22:59,714] Trial 14 finished with value: 0.7219954058158099 and parameters: {'long_window': 296, 'short_window': 8}. Best is trial 11 with value: 0.7469807476393641.
# [I 2025-03-02 20:23:03,513] Trial 15 finished with value: 0.7210060815434707 and parameters: {'long_window': 373, 'short_window': 197}. Best is trial 11 with value: 0.7469807476393641.
# [I 2025-03-02 20:23:07,289] Trial 16 finished with value: 0.7369481566288651 and parameters: {'long_window': 274, 'short_window': 155}. Best is trial 11 with value: 0.7469807476393641.
# [I 2025-03-02 20:23:11,027] Trial 17 finished with value: 0.6458836486607223 and parameters: {'long_window': 491, 'short_window': 208}. Best is trial 11 with value: 0.7469807476393641.
# [I 2025-03-02 20:23:14,774] Trial 18 finished with value: 0.6840268068521167 and parameters: {'long_window': 373, 'short_window': 120}. Best is trial 11 with value: 0.7469807476393641.
# [I 2025-03-02 20:23:18,518] Trial 19 finished with value: 0.7105540276283582 and parameters: {'long_window': 431, 'short_window': 165}. Best is trial 11 with value: 0.7469807476393641.
# [I 2025-03-02 20:23:18,530] Trial 20 finished with value: -1.0 and parameters: {'long_window': 194, 'short_window': 223}. Best is trial 11 with value: 0.7469807476393641.
# [I 2025-03-02 20:23:22,307] Trial 21 finished with value: 0.7413926523439156 and parameters: {'long_window': 318, 'short_window': 180}. Best is trial 11 with value: 0.7469807476393641.
# [I 2025-03-02 20:23:26,106] Trial 22 finished with value: 0.6796157555488569 and parameters: {'long_window': 269, 'short_window': 191}. Best is trial 11 with value: 0.7469807476393641.
# [I 2025-03-02 20:23:29,943] Trial 23 finished with value: 0.7253547572940398 and parameters: {'long_window': 331, 'short_window': 134}. Best is trial 11 with value: 0.7469807476393641.
# [I 2025-03-02 20:23:33,729] Trial 24 finished with value: 0.7243644986055461 and parameters: {'long_window': 305, 'short_window': 170}. Best is trial 11 with value: 0.7469807476393641.
# [I 2025-03-02 20:23:37,478] Trial 25 finished with value: 0.6823077723354356 and parameters: {'long_window': 354, 'short_window': 217}. Best is trial 11 with value: 0.7469807476393641.
# [I 2025-03-02 20:23:41,224] Trial 26 finished with value: 0.6846081754611639 and parameters: {'long_window': 409, 'short_window': 104}. Best is trial 11 with value: 0.7469807476393641.
# [I 2025-03-02 20:23:45,001] Trial 27 finished with value: 0.6891467639467758 and parameters: {'long_window': 244, 'short_window': 145}. Best is trial 11 with value: 0.7469807476393641.
# [I 2025-03-02 20:23:48,763] Trial 28 finished with value: 0.6727810840405419 and parameters: {'long_window': 286, 'short_window': 199}. Best is trial 11 with value: 0.7469807476393641.
# [I 2025-03-02 20:23:48,778] Trial 29 finished with value: -1.0 and parameters: {'long_window': 229, 'short_window': 251}. Best is trial 11 with value: 0.7469807476393641.
# [I 2025-03-02 20:23:48,790] Trial 30 finished with value: -1.0 and parameters: {'long_window': 196, 'short_window': 232}. Best is trial 11 with value: 0.7469807476393641.
# [I 2025-03-02 20:23:52,550] Trial 31 finished with value: 0.7554915216984377 and parameters: {'long_window': 320, 'short_window': 183}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:23:56,291] Trial 32 finished with value: 0.7004436417323417 and parameters: {'long_window': 396, 'short_window': 168}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:24:00,039] Trial 33 finished with value: 0.6902902748276866 and parameters: {'long_window': 351, 'short_window': 180}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:24:04,210] Trial 34 finished with value: 0.7252669637446411 and parameters: {'long_window': 309, 'short_window': 207}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:24:07,967] Trial 35 finished with value: 0.7175687694107792 and parameters: {'long_window': 270, 'short_window': 147}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:24:11,731] Trial 36 finished with value: 0.6857864161924007 and parameters: {'long_window': 347, 'short_window': 230}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:24:15,500] Trial 37 finished with value: 0.7336266607493731 and parameters: {'long_window': 315, 'short_window': 159}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:24:19,260] Trial 38 finished with value: 0.7047425252344334 and parameters: {'long_window': 377, 'short_window': 181}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:24:19,275] Trial 39 finished with value: -1.0 and parameters: {'long_window': 143, 'short_window': 210}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:24:23,051] Trial 40 finished with value: 0.6988653231712246 and parameters: {'long_window': 255, 'short_window': 187}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:24:26,801] Trial 41 finished with value: 0.7449679834562248 and parameters: {'long_window': 323, 'short_window': 178}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:24:30,561] Trial 42 finished with value: 0.7326813061688526 and parameters: {'long_window': 337, 'short_window': 173}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:24:34,323] Trial 43 finished with value: 0.7340476549834372 and parameters: {'long_window': 294, 'short_window': 197}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:24:38,085] Trial 44 finished with value: 0.6831751483675615 and parameters: {'long_window': 220, 'short_window': 126}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:24:41,851] Trial 45 finished with value: 0.7297701257215029 and parameters: {'long_window': 321, 'short_window': 151}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:24:45,596] Trial 46 finished with value: 0.7160727948387077 and parameters: {'long_window': 364, 'short_window': 177}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:24:49,349] Trial 47 finished with value: 0.7300184076472191 and parameters: {'long_window': 425, 'short_window': 112}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:24:53,122] Trial 48 finished with value: 0.6814733467405483 and parameters: {'long_window': 286, 'short_window': 241}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:24:56,863] Trial 49 finished with value: 0.7259109153907377 and parameters: {'long_window': 393, 'short_window': 141}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:25:00,640] Trial 50 finished with value: 0.715463568552052 and parameters: {'long_window': 329, 'short_window': 162}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:25:04,414] Trial 51 finished with value: 0.7111525217952647 and parameters: {'long_window': 306, 'short_window': 191}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:25:08,192] Trial 52 finished with value: 0.7324649434848249 and parameters: {'long_window': 253, 'short_window': 199}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:25:11,953] Trial 53 finished with value: 0.714444406219753 and parameters: {'long_window': 325, 'short_window': 214}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:25:15,703] Trial 54 finished with value: 0.6776949550094126 and parameters: {'long_window': 344, 'short_window': 75}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:25:19,444] Trial 55 finished with value: 0.7335845703643844 and parameters: {'long_window': 365, 'short_window': 25}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:25:23,211] Trial 56 finished with value: 0.7089791051725739 and parameters: {'long_window': 288, 'short_window': 186}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:25:27,367] Trial 57 finished with value: 0.7266102360049203 and parameters: {'long_window': 265, 'short_window': 157}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:25:31,115] Trial 58 finished with value: 0.6949821775823619 and parameters: {'long_window': 440, 'short_window': 203}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:25:34,910] Trial 59 finished with value: 0.7204367250688513 and parameters: {'long_window': 302, 'short_window': 223}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:25:38,659] Trial 60 finished with value: 0.7337837711497625 and parameters: {'long_window': 358, 'short_window': 172}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:25:42,393] Trial 61 finished with value: 0.6781532248805193 and parameters: {'long_window': 444, 'short_window': 84}. Best is trial 31 with value: 0.7554915216984377.
# [I 2025-03-02 20:25:46,259] Trial 62 finished with value: 0.7592456291888877 and parameters: {'long_window': 485, 'short_window': 101}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:25:50,038] Trial 63 finished with value: 0.6628279829711746 and parameters: {'long_window': 483, 'short_window': 191}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:25:50,057] Trial 64 finished with value: -1.0 and parameters: {'long_window': 77, 'short_window': 135}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:25:53,795] Trial 65 finished with value: 0.692434442831386 and parameters: {'long_window': 394, 'short_window': 102}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:25:57,595] Trial 66 finished with value: 0.6903615602283538 and parameters: {'long_window': 176, 'short_window': 88}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:26:01,349] Trial 67 finished with value: 0.6976789024665608 and parameters: {'long_window': 462, 'short_window': 165}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:26:05,100] Trial 68 finished with value: 0.67682475948426 and parameters: {'long_window': 318, 'short_window': 67}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:26:08,865] Trial 69 finished with value: 0.6860305060330122 and parameters: {'long_window': 284, 'short_window': 178}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:26:12,608] Trial 70 finished with value: 0.718819625692233 and parameters: {'long_window': 411, 'short_window': 121}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:26:16,349] Trial 71 finished with value: 0.6909289521375868 and parameters: {'long_window': 474, 'short_window': 95}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:26:20,096] Trial 72 finished with value: 0.7300188533975992 and parameters: {'long_window': 462, 'short_window': 110}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:26:23,860] Trial 73 finished with value: 0.7309197848616898 and parameters: {'long_window': 337, 'short_window': 185}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:26:27,607] Trial 74 finished with value: 0.6640886172262354 and parameters: {'long_window': 498, 'short_window': 172}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:26:31,378] Trial 75 finished with value: 0.712369377338211 and parameters: {'long_window': 300, 'short_window': 55}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:26:35,143] Trial 76 finished with value: 0.6964356116509756 and parameters: {'long_window': 239, 'short_window': 97}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:26:38,912] Trial 77 finished with value: 0.7283350036030904 and parameters: {'long_window': 344, 'short_window': 192}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:26:42,677] Trial 78 finished with value: 0.7344627471557668 and parameters: {'long_window': 277, 'short_window': 153}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:26:46,429] Trial 79 finished with value: 0.6986690861289728 and parameters: {'long_window': 382, 'short_window': 204}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:26:50,185] Trial 80 finished with value: 0.6678185237143098 and parameters: {'long_window': 413, 'short_window': 178}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:26:54,357] Trial 81 finished with value: 0.7048087171529911 and parameters: {'long_window': 322, 'short_window': 166}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:26:58,127] Trial 82 finished with value: 0.7369864506043566 and parameters: {'long_window': 312, 'short_window': 141}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:27:01,898] Trial 83 finished with value: 0.7369864506043566 and parameters: {'long_window': 312, 'short_window': 141}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:27:05,655] Trial 84 finished with value: 0.7046146833732266 and parameters: {'long_window': 330, 'short_window': 117}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:27:09,412] Trial 85 finished with value: 0.6874956741153955 and parameters: {'long_window': 357, 'short_window': 196}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:27:13,206] Trial 86 finished with value: 0.6721861834072037 and parameters: {'long_window': 256, 'short_window': 213}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:27:16,983] Trial 87 finished with value: 0.7333478426360306 and parameters: {'long_window': 294, 'short_window': 183}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:27:20,756] Trial 88 finished with value: 0.7405206790942437 and parameters: {'long_window': 313, 'short_window': 158}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:27:24,514] Trial 89 finished with value: 0.7004072205758238 and parameters: {'long_window': 370, 'short_window': 172}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:27:28,282] Trial 90 finished with value: 0.6792982870445057 and parameters: {'long_window': 339, 'short_window': 159}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:27:32,079] Trial 91 finished with value: 0.7260740479735868 and parameters: {'long_window': 314, 'short_window': 129}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:27:35,847] Trial 92 finished with value: 0.7403923417789287 and parameters: {'long_window': 275, 'short_window': 146}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:27:39,618] Trial 93 finished with value: 0.716801512959827 and parameters: {'long_window': 271, 'short_window': 147}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:27:43,402] Trial 94 finished with value: 0.7085079009521121 and parameters: {'long_window': 280, 'short_window': 166}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:27:47,153] Trial 95 finished with value: 0.7369797108939536 and parameters: {'long_window': 295, 'short_window': 151}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:27:50,952] Trial 96 finished with value: 0.6623037656625796 and parameters: {'long_window': 259, 'short_window': 177}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:27:54,723] Trial 97 finished with value: 0.6860556194454789 and parameters: {'long_window': 213, 'short_window': 161}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:27:58,483] Trial 98 finished with value: 0.6974890457557666 and parameters: {'long_window': 351, 'short_window': 188}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:28:02,235] Trial 99 finished with value: 0.6928984505778871 and parameters: {'long_window': 480, 'short_window': 201}. Best is trial 62 with value: 0.7592456291888877.
# [I 2025-03-02 20:28:05,982] A new study created in memory with name: no-name-c87837db-bfaf-4b97-9d60-f77ca4f148ce
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-03-02 20:28:05,990] Trial 0 finished with value: -1.0 and parameters: {'long_window': 218, 'short_window': 240}. Best is trial 0 with value: -1.0.
# [I 2025-03-02 20:28:06,528] Trial 1 finished with value: 1.8809612392365953 and parameters: {'long_window': 380, 'short_window': 153}. Best is trial 1 with value: 1.8809612392365953.
# [I 2025-03-02 20:28:07,133] Trial 2 finished with value: 1.4282293898786864 and parameters: {'long_window': 120, 'short_window': 43}. Best is trial 1 with value: 1.8809612392365953.
# [I 2025-03-02 20:28:07,135] Trial 3 finished with value: -1.0 and parameters: {'long_window': 76, 'short_window': 219}. Best is trial 1 with value: 1.8809612392365953.
# [I 2025-03-02 20:28:07,689] Trial 4 finished with value: 1.8025861710834405 and parameters: {'long_window': 321, 'short_window': 180}. Best is trial 1 with value: 1.8809612392365953.
# [I 2025-03-02 20:28:07,692] Trial 5 finished with value: -1.0 and parameters: {'long_window': 59, 'short_window': 245}. Best is trial 1 with value: 1.8809612392365953.
# [I 2025-03-02 20:28:08,216] Trial 6 finished with value: 2.037698028770274 and parameters: {'long_window': 425, 'short_window': 57}. Best is trial 6 with value: 2.037698028770274.
# [I 2025-03-02 20:28:08,828] Trial 7 finished with value: 1.3850005888142385 and parameters: {'long_window': 132, 'short_window': 50}. Best is trial 6 with value: 2.037698028770274.
# [I 2025-03-02 20:28:09,415] Trial 8 finished with value: 1.6710666495171804 and parameters: {'long_window': 187, 'short_window': 135}. Best is trial 6 with value: 2.037698028770274.
# [I 2025-03-02 20:28:09,990] Trial 9 finished with value: 1.6755414185922601 and parameters: {'long_window': 244, 'short_window': 77}. Best is trial 6 with value: 2.037698028770274.
# [I 2025-03-02 20:28:10,507] Trial 10 finished with value: 2.1113701465760912 and parameters: {'long_window': 491, 'short_window': 6}. Best is trial 10 with value: 2.1113701465760912.
# [I 2025-03-02 20:28:11,032] Trial 11 finished with value: 2.117767885729392 and parameters: {'long_window': 487, 'short_window': 6}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 20:28:11,552] Trial 12 finished with value: 2.0821836051338436 and parameters: {'long_window': 496, 'short_window': 12}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 20:28:12,072] Trial 13 finished with value: 2.1062644561877657 and parameters: {'long_window': 494, 'short_window': 6}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 20:28:12,615] Trial 14 finished with value: 1.9229535203854589 and parameters: {'long_window': 411, 'short_window': 99}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 20:28:13,165] Trial 15 finished with value: 1.8099120245142013 and parameters: {'long_window': 348, 'short_window': 101}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 20:28:13,702] Trial 16 finished with value: 1.9384173978229438 and parameters: {'long_window': 453, 'short_window': 30}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 20:28:14,262] Trial 17 finished with value: 1.8190555174873893 and parameters: {'long_window': 321, 'short_window': 83}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 20:28:14,792] Trial 18 finished with value: 1.968434416112611 and parameters: {'long_window': 456, 'short_window': 6}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 20:28:15,363] Trial 19 finished with value: 1.502462131809011 and parameters: {'long_window': 283, 'short_window': 31}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 20:28:15,909] Trial 20 finished with value: 1.8625352674451778 and parameters: {'long_window': 387, 'short_window': 176}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 20:28:16,429] Trial 21 finished with value: 2.090694988652949 and parameters: {'long_window': 498, 'short_window': 9}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 20:28:16,955] Trial 22 finished with value: 2.023850048473789 and parameters: {'long_window': 470, 'short_window': 29}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 20:28:17,493] Trial 23 finished with value: 1.9793652170362905 and parameters: {'long_window': 419, 'short_window': 60}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 20:28:18,009] Trial 24 finished with value: 2.079199668070158 and parameters: {'long_window': 497, 'short_window': 5}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 20:28:18,540] Trial 25 finished with value: 1.9828295631131836 and parameters: {'long_window': 447, 'short_window': 74}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 20:28:19,089] Trial 26 finished with value: 1.8018310971687095 and parameters: {'long_window': 372, 'short_window': 36}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 20:28:19,614] Trial 27 finished with value: 2.1236824187362147 and parameters: {'long_window': 475, 'short_window': 111}. Best is trial 27 with value: 2.1236824187362147.
# [I 2025-03-02 20:28:20,151] Trial 28 finished with value: 2.042865134303952 and parameters: {'long_window': 427, 'short_window': 120}. Best is trial 27 with value: 2.1236824187362147.
# [I 2025-03-02 20:28:20,680] Trial 29 finished with value: 2.1152589038764096 and parameters: {'long_window': 467, 'short_window': 223}. Best is trial 27 with value: 2.1236824187362147.
# [I 2025-03-02 20:28:21,246] Trial 30 finished with value: 1.6237366130062523 and parameters: {'long_window': 343, 'short_window': 216}. Best is trial 27 with value: 2.1236824187362147.
# [I 2025-03-02 20:28:21,777] Trial 31 finished with value: 2.1152589038764096 and parameters: {'long_window': 467, 'short_window': 183}. Best is trial 27 with value: 2.1236824187362147.
# [I 2025-03-02 20:28:22,327] Trial 32 finished with value: 1.7172297180096643 and parameters: {'long_window': 390, 'short_window': 219}. Best is trial 27 with value: 2.1236824187362147.
# [I 2025-03-02 20:28:22,864] Trial 33 finished with value: 2.1374426796247747 and parameters: {'long_window': 460, 'short_window': 195}. Best is trial 33 with value: 2.1374426796247747.
# [I 2025-03-02 20:28:23,403] Trial 34 finished with value: 1.8907473334798999 and parameters: {'long_window': 434, 'short_window': 199}. Best is trial 33 with value: 2.1374426796247747.
# [I 2025-03-02 20:28:23,951] Trial 35 finished with value: 1.6810900662620132 and parameters: {'long_window': 402, 'short_window': 231}. Best is trial 33 with value: 2.1374426796247747.
# [I 2025-03-02 20:28:24,502] Trial 36 finished with value: 2.128071759620883 and parameters: {'long_window': 470, 'short_window': 153}. Best is trial 33 with value: 2.1374426796247747.
# [I 2025-03-02 20:28:25,053] Trial 37 finished with value: 1.9181022213443213 and parameters: {'long_window': 368, 'short_window': 157}. Best is trial 33 with value: 2.1374426796247747.
# [I 2025-03-02 20:28:25,652] Trial 38 finished with value: 1.666004728478677 and parameters: {'long_window': 189, 'short_window': 153}. Best is trial 33 with value: 2.1374426796247747.
# [I 2025-03-02 20:28:26,225] Trial 39 finished with value: 1.836701148058023 and parameters: {'long_window': 293, 'short_window': 136}. Best is trial 33 with value: 2.1374426796247747.
# [I 2025-03-02 20:28:26,763] Trial 40 finished with value: 1.948979105870827 and parameters: {'long_window': 442, 'short_window': 168}. Best is trial 33 with value: 2.1374426796247747.
# [I 2025-03-02 20:28:27,294] Trial 41 finished with value: 2.032144458319291 and parameters: {'long_window': 467, 'short_window': 198}. Best is trial 33 with value: 2.1374426796247747.
# [I 2025-03-02 20:28:27,826] Trial 42 finished with value: 2.1688743201021254 and parameters: {'long_window': 471, 'short_window': 236}. Best is trial 42 with value: 2.1688743201021254.
# [I 2025-03-02 20:28:28,744] Trial 43 finished with value: 2.1486444061922767 and parameters: {'long_window': 473, 'short_window': 126}. Best is trial 42 with value: 2.1688743201021254.
# [I 2025-03-02 20:28:29,291] Trial 44 finished with value: 1.9756630275491536 and parameters: {'long_window': 430, 'short_window': 118}. Best is trial 42 with value: 2.1688743201021254.
# [I 2025-03-02 20:28:29,817] Trial 45 finished with value: 2.142123287398858 and parameters: {'long_window': 474, 'short_window': 248}. Best is trial 42 with value: 2.1688743201021254.
# [I 2025-03-02 20:28:30,367] Trial 46 finished with value: 1.7720333157823853 and parameters: {'long_window': 404, 'short_window': 244}. Best is trial 42 with value: 2.1688743201021254.
# [I 2025-03-02 20:28:30,900] Trial 47 finished with value: 1.8317869993622042 and parameters: {'long_window': 444, 'short_window': 200}. Best is trial 42 with value: 2.1688743201021254.
# [I 2025-03-02 20:28:30,916] Trial 48 finished with value: -1.0 and parameters: {'long_window': 103, 'short_window': 249}. Best is trial 42 with value: 2.1688743201021254.
# [I 2025-03-02 20:28:31,504] Trial 49 finished with value: 1.6717986870045356 and parameters: {'long_window': 231, 'short_window': 143}. Best is trial 42 with value: 2.1688743201021254.
# [I 2025-03-02 20:28:32,018] A new study created in memory with name: no-name-09f131a8-c5ed-4930-be55-85229bf1cd8a
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-03-02 20:28:32,025] Trial 0 finished with value: -1.0 and parameters: {'long_window': 218, 'short_window': 240}. Best is trial 0 with value: -1.0.
# [I 2025-03-02 20:28:33,204] Trial 1 finished with value: 0.8320419679114547 and parameters: {'long_window': 380, 'short_window': 153}. Best is trial 1 with value: 0.8320419679114547.
# [I 2025-03-02 20:28:34,421] Trial 2 finished with value: 0.6243271283554286 and parameters: {'long_window': 120, 'short_window': 43}. Best is trial 1 with value: 0.8320419679114547.
# [I 2025-03-02 20:28:34,423] Trial 3 finished with value: -1.0 and parameters: {'long_window': 76, 'short_window': 219}. Best is trial 1 with value: 0.8320419679114547.
# [I 2025-03-02 20:28:35,591] Trial 4 finished with value: 0.8754914791304916 and parameters: {'long_window': 321, 'short_window': 180}. Best is trial 4 with value: 0.8754914791304916.
# [I 2025-03-02 20:28:35,593] Trial 5 finished with value: -1.0 and parameters: {'long_window': 59, 'short_window': 245}. Best is trial 4 with value: 0.8754914791304916.
# [I 2025-03-02 20:28:36,736] Trial 6 finished with value: 0.9775378996792822 and parameters: {'long_window': 425, 'short_window': 57}. Best is trial 6 with value: 0.9775378996792822.
# [I 2025-03-02 20:28:37,960] Trial 7 finished with value: 0.47368399553366164 and parameters: {'long_window': 132, 'short_window': 50}. Best is trial 6 with value: 0.9775378996792822.
# [I 2025-03-02 20:28:39,164] Trial 8 finished with value: 0.8084688610829058 and parameters: {'long_window': 187, 'short_window': 135}. Best is trial 6 with value: 0.9775378996792822.
# [I 2025-03-02 20:28:40,350] Trial 9 finished with value: 0.839472498866702 and parameters: {'long_window': 244, 'short_window': 77}. Best is trial 6 with value: 0.9775378996792822.
# [I 2025-03-02 20:28:41,484] Trial 10 finished with value: 0.9362910267543566 and parameters: {'long_window': 491, 'short_window': 6}. Best is trial 6 with value: 0.9775378996792822.
# [I 2025-03-02 20:28:42,638] Trial 11 finished with value: 0.9537763874437132 and parameters: {'long_window': 487, 'short_window': 6}. Best is trial 6 with value: 0.9775378996792822.
# [I 2025-03-02 20:28:43,785] Trial 12 finished with value: 0.9178621097234415 and parameters: {'long_window': 493, 'short_window': 90}. Best is trial 6 with value: 0.9775378996792822.
# [I 2025-03-02 20:28:44,942] Trial 13 finished with value: 0.9856785397826411 and parameters: {'long_window': 419, 'short_window': 8}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:28:46,112] Trial 14 finished with value: 0.9101792789793332 and parameters: {'long_window': 403, 'short_window': 99}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:28:47,288] Trial 15 finished with value: 0.9280741092372212 and parameters: {'long_window': 413, 'short_window': 40}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:28:48,512] Trial 16 finished with value: 0.8767457356355979 and parameters: {'long_window': 311, 'short_window': 55}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:28:49,782] Trial 17 finished with value: 0.9187783188017828 and parameters: {'long_window': 353, 'short_window': 24}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:28:50,942] Trial 18 finished with value: 0.9287679076894548 and parameters: {'long_window': 440, 'short_window': 108}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:28:52,101] Trial 19 finished with value: 0.935906583782433 and parameters: {'long_window': 437, 'short_window': 66}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:28:53,290] Trial 20 finished with value: 0.7700837319077004 and parameters: {'long_window': 282, 'short_window': 22}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:28:54,443] Trial 21 finished with value: 0.9763532374481466 and parameters: {'long_window': 466, 'short_window': 10}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:28:55,601] Trial 22 finished with value: 0.9701869726389842 and parameters: {'long_window': 439, 'short_window': 29}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:28:56,772] Trial 23 finished with value: 0.8907319991616296 and parameters: {'long_window': 367, 'short_window': 7}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:28:57,926] Trial 24 finished with value: 0.953771209943841 and parameters: {'long_window': 466, 'short_window': 79}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:28:59,103] Trial 25 finished with value: 0.85975350640549 and parameters: {'long_window': 338, 'short_window': 60}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:00,286] Trial 26 finished with value: 0.8928751593414426 and parameters: {'long_window': 387, 'short_window': 120}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:01,435] Trial 27 finished with value: 0.9781277985877687 and parameters: {'long_window': 455, 'short_window': 28}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:02,628] Trial 28 finished with value: 0.878421992087599 and parameters: {'long_window': 296, 'short_window': 30}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:03,790] Trial 29 finished with value: 0.8926110285134041 and parameters: {'long_window': 414, 'short_window': 70}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:04,996] Trial 30 finished with value: 0.8310025687747405 and parameters: {'long_window': 242, 'short_window': 166}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:06,158] Trial 31 finished with value: 0.936537168371752 and parameters: {'long_window': 459, 'short_window': 20}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:07,308] Trial 32 finished with value: 0.9506283928289215 and parameters: {'long_window': 469, 'short_window': 38}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:08,470] Trial 33 finished with value: 0.9805437459490001 and parameters: {'long_window': 426, 'short_window': 17}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:09,639] Trial 34 finished with value: 0.9057240587568648 and parameters: {'long_window': 389, 'short_window': 44}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:10,816] Trial 35 finished with value: 0.7575426637470882 and parameters: {'long_window': 417, 'short_window': 219}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:11,989] Trial 36 finished with value: 0.8979805234673846 and parameters: {'long_window': 360, 'short_window': 50}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:13,146] Trial 37 finished with value: 0.9291914197318475 and parameters: {'long_window': 437, 'short_window': 20}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:14,356] Trial 38 finished with value: 0.7599802229508786 and parameters: {'long_window': 189, 'short_window': 35}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:15,579] Trial 39 finished with value: 0.878279264196057 and parameters: {'long_window': 333, 'short_window': 87}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:16,911] Trial 40 finished with value: 0.7126211975758336 and parameters: {'long_window': 383, 'short_window': 204}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:18,107] Trial 41 finished with value: 0.9535842648620376 and parameters: {'long_window': 459, 'short_window': 17}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:19,290] Trial 42 finished with value: 0.9230480199106506 and parameters: {'long_window': 480, 'short_window': 6}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:20,480] Trial 43 finished with value: 0.9703403949765081 and parameters: {'long_window': 427, 'short_window': 15}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:21,665] Trial 44 finished with value: 0.9581206882012597 and parameters: {'long_window': 500, 'short_window': 51}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:22,847] Trial 45 finished with value: 0.9268933015559078 and parameters: {'long_window': 452, 'short_window': 36}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:24,043] Trial 46 finished with value: 0.924112735293918 and parameters: {'long_window': 405, 'short_window': 13}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:25,244] Trial 47 finished with value: 0.9384358677752324 and parameters: {'long_window': 481, 'short_window': 29}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:25,260] Trial 48 finished with value: -1.0 and parameters: {'long_window': 103, 'short_window': 133}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:26,466] Trial 49 finished with value: 0.9508668984167946 and parameters: {'long_window': 392, 'short_window': 61}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 20:29:27,023] A new study created in memory with name: no-name-98e9e031-ef60-451e-a238-fe30722b335e
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-03-02 20:29:27,031] Trial 0 finished with value: -1.0 and parameters: {'long_window': 218, 'short_window': 240}. Best is trial 0 with value: -1.0.
# [I 2025-03-02 20:29:28,901] Trial 1 finished with value: 0.7520123629646583 and parameters: {'long_window': 380, 'short_window': 153}. Best is trial 1 with value: 0.7520123629646583.
# [I 2025-03-02 20:29:30,834] Trial 2 finished with value: 0.594198544918815 and parameters: {'long_window': 120, 'short_window': 43}. Best is trial 1 with value: 0.7520123629646583.
# [I 2025-03-02 20:29:30,836] Trial 3 finished with value: -1.0 and parameters: {'long_window': 76, 'short_window': 219}. Best is trial 1 with value: 0.7520123629646583.
# [I 2025-03-02 20:29:32,701] Trial 4 finished with value: 0.7692314654179755 and parameters: {'long_window': 321, 'short_window': 180}. Best is trial 4 with value: 0.7692314654179755.
# [I 2025-03-02 20:29:32,704] Trial 5 finished with value: -1.0 and parameters: {'long_window': 59, 'short_window': 245}. Best is trial 4 with value: 0.7692314654179755.
# [I 2025-03-02 20:29:34,556] Trial 6 finished with value: 0.8244370500503972 and parameters: {'long_window': 425, 'short_window': 57}. Best is trial 6 with value: 0.8244370500503972.
# [I 2025-03-02 20:29:36,458] Trial 7 finished with value: 0.4526114074834083 and parameters: {'long_window': 132, 'short_window': 50}. Best is trial 6 with value: 0.8244370500503972.
# [I 2025-03-02 20:29:38,359] Trial 8 finished with value: 0.7502306234536907 and parameters: {'long_window': 187, 'short_window': 135}. Best is trial 6 with value: 0.8244370500503972.
# [I 2025-03-02 20:29:40,235] Trial 9 finished with value: 0.7299529046996923 and parameters: {'long_window': 244, 'short_window': 77}. Best is trial 6 with value: 0.8244370500503972.
# [I 2025-03-02 20:29:42,070] Trial 10 finished with value: 0.8200366603458198 and parameters: {'long_window': 491, 'short_window': 6}. Best is trial 6 with value: 0.8244370500503972.
# [I 2025-03-02 20:29:43,903] Trial 11 finished with value: 0.8139479164105892 and parameters: {'long_window': 487, 'short_window': 6}. Best is trial 6 with value: 0.8244370500503972.
# [I 2025-03-02 20:29:45,755] Trial 12 finished with value: 0.7747396327172692 and parameters: {'long_window': 493, 'short_window': 90}. Best is trial 6 with value: 0.8244370500503972.
# [I 2025-03-02 20:29:47,600] Trial 13 finished with value: 0.8470241793285519 and parameters: {'long_window': 419, 'short_window': 8}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 20:29:49,463] Trial 14 finished with value: 0.7774959320094469 and parameters: {'long_window': 403, 'short_window': 99}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 20:29:51,320] Trial 15 finished with value: 0.8130154367611737 and parameters: {'long_window': 413, 'short_window': 40}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 20:29:53,199] Trial 16 finished with value: 0.7771861001449049 and parameters: {'long_window': 311, 'short_window': 55}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 20:29:55,063] Trial 17 finished with value: 0.8045630406167217 and parameters: {'long_window': 353, 'short_window': 24}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 20:29:56,910] Trial 18 finished with value: 0.8118949197143817 and parameters: {'long_window': 440, 'short_window': 108}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 20:29:58,756] Trial 19 finished with value: 0.8274564843210699 and parameters: {'long_window': 437, 'short_window': 66}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 20:30:00,664] Trial 20 finished with value: 0.7938934630993069 and parameters: {'long_window': 287, 'short_window': 74}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 20:30:02,522] Trial 21 finished with value: 0.8266941503363237 and parameters: {'long_window': 429, 'short_window': 20}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 20:30:04,382] Trial 22 finished with value: 0.8032801311618897 and parameters: {'long_window': 451, 'short_window': 28}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 20:30:06,235] Trial 23 finished with value: 0.829311863022629 and parameters: {'long_window': 376, 'short_window': 21}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 20:30:08,207] Trial 24 finished with value: 0.7692091548405354 and parameters: {'long_window': 363, 'short_window': 72}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 20:30:10,204] Trial 25 finished with value: 0.8223167826867335 and parameters: {'long_window': 340, 'short_window': 6}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 20:30:12,136] Trial 26 finished with value: 0.8055918378285087 and parameters: {'long_window': 389, 'short_window': 31}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 20:30:14,005] Trial 27 finished with value: 0.7807774277730928 and parameters: {'long_window': 462, 'short_window': 119}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 20:30:15,880] Trial 28 finished with value: 0.8052155807162271 and parameters: {'long_window': 296, 'short_window': 60}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 20:30:17,761] Trial 29 finished with value: 0.7892589559538128 and parameters: {'long_window': 270, 'short_window': 83}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 20:30:19,624] Trial 30 finished with value: 0.8472206142703675 and parameters: {'long_window': 375, 'short_window': 23}. Best is trial 30 with value: 0.8472206142703675.
# [I 2025-03-02 20:30:21,489] Trial 31 finished with value: 0.8550809811155904 and parameters: {'long_window': 379, 'short_window': 20}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 20:30:23,345] Trial 32 finished with value: 0.829311863022629 and parameters: {'long_window': 376, 'short_window': 20}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 20:30:25,184] Trial 33 finished with value: 0.810047356489802 and parameters: {'long_window': 402, 'short_window': 38}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 20:30:27,049] Trial 34 finished with value: 0.7321804299915521 and parameters: {'long_window': 334, 'short_window': 186}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 20:30:29,337] Trial 35 finished with value: 0.7765290963078701 and parameters: {'long_window': 371, 'short_window': 16}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 20:30:31,225] Trial 36 finished with value: 0.6820230476213853 and parameters: {'long_window': 262, 'short_window': 44}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 20:30:33,097] Trial 37 finished with value: 0.7014626020813808 and parameters: {'long_window': 464, 'short_window': 163}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 20:30:33,111] Trial 38 finished with value: -1.0 and parameters: {'long_window': 189, 'short_window': 212}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 20:30:34,986] Trial 39 finished with value: 0.770200646624099 and parameters: {'long_window': 320, 'short_window': 35}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 20:30:36,849] Trial 40 finished with value: 0.8165279178226899 and parameters: {'long_window': 393, 'short_window': 52}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 20:30:38,729] Trial 41 finished with value: 0.815138216677231 and parameters: {'long_window': 377, 'short_window': 20}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 20:30:40,608] Trial 42 finished with value: 0.8192137651723559 and parameters: {'long_window': 369, 'short_window': 16}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 20:30:42,483] Trial 43 finished with value: 0.8359752994095581 and parameters: {'long_window': 353, 'short_window': 6}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 20:30:44,334] Trial 44 finished with value: 0.707498100686088 and parameters: {'long_window': 350, 'short_window': 8}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 20:30:46,172] Trial 45 finished with value: 0.8070470923744154 and parameters: {'long_window': 414, 'short_window': 32}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 20:30:48,049] Trial 46 finished with value: 0.7948667488080866 and parameters: {'long_window': 305, 'short_window': 143}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 20:30:49,973] Trial 47 finished with value: 0.701887789275729 and parameters: {'long_window': 220, 'short_window': 46}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 20:30:51,849] Trial 48 finished with value: 0.7485650916634171 and parameters: {'long_window': 327, 'short_window': 11}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 20:30:53,702] Trial 49 finished with value: 0.8258087878717705 and parameters: {'long_window': 419, 'short_window': 27}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 20:30:54,256] A new study created in memory with name: no-name-b0e1caeb-84d0-4520-b131-a3f9aab89e4f
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-03-02 20:30:54,264] Trial 0 finished with value: -1.0 and parameters: {'long_window': 218, 'short_window': 240}. Best is trial 0 with value: -1.0.
# [I 2025-03-02 20:30:56,782] Trial 1 finished with value: 0.7641308974129813 and parameters: {'long_window': 380, 'short_window': 153}. Best is trial 1 with value: 0.7641308974129813.
# [I 2025-03-02 20:30:59,343] Trial 2 finished with value: 0.7654482963758183 and parameters: {'long_window': 120, 'short_window': 43}. Best is trial 2 with value: 0.7654482963758183.
# [I 2025-03-02 20:30:59,345] Trial 3 finished with value: -1.0 and parameters: {'long_window': 76, 'short_window': 219}. Best is trial 2 with value: 0.7654482963758183.
# [I 2025-03-02 20:31:01,881] Trial 4 finished with value: 0.791437253216959 and parameters: {'long_window': 321, 'short_window': 180}. Best is trial 4 with value: 0.791437253216959.
# [I 2025-03-02 20:31:01,883] Trial 5 finished with value: -1.0 and parameters: {'long_window': 59, 'short_window': 245}. Best is trial 4 with value: 0.791437253216959.
# [I 2025-03-02 20:31:04,375] Trial 6 finished with value: 0.8183918949602138 and parameters: {'long_window': 425, 'short_window': 57}. Best is trial 6 with value: 0.8183918949602138.
# [I 2025-03-02 20:31:06,938] Trial 7 finished with value: 0.5288121041983879 and parameters: {'long_window': 132, 'short_window': 50}. Best is trial 6 with value: 0.8183918949602138.
# [I 2025-03-02 20:31:09,490] Trial 8 finished with value: 0.7167525590311088 and parameters: {'long_window': 187, 'short_window': 135}. Best is trial 6 with value: 0.8183918949602138.
# ...
# [I 2025-03-02 20:45:31,496] Trial 14 finished with value: 0.759689032279256 and parameters: {'long_window': 489, 'short_window': 99}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:45:34,522] Trial 15 finished with value: 0.7642745164564797 and parameters: {'long_window': 424, 'short_window': 105}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:45:37,572] Trial 16 finished with value: 0.7608879044621715 and parameters: {'long_window': 293, 'short_window': 112}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:45:40,631] Trial 17 finished with value: 0.7267010728104591 and parameters: {'long_window': 385, 'short_window': 144}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:45:43,686] Trial 18 finished with value: 0.7616966492798142 and parameters: {'long_window': 440, 'short_window': 11}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:45:46,799] Trial 19 finished with value: 0.7739917456104559 and parameters: {'long_window': 353, 'short_window': 91}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:45:49,837] Trial 20 finished with value: 0.795546113774779 and parameters: {'long_window': 359, 'short_window': 76}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:45:52,878] Trial 21 finished with value: 0.7406863088801 and parameters: {'long_window': 370, 'short_window': 78}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:45:55,930] Trial 22 finished with value: 0.7958283617694262 and parameters: {'long_window': 362, 'short_window': 78}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:45:59,001] Trial 23 finished with value: 0.6827831569585942 and parameters: {'long_window': 267, 'short_window': 67}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:46:02,053] Trial 24 finished with value: 0.7533480727322737 and parameters: {'long_window': 448, 'short_window': 33}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:46:05,103] Trial 25 finished with value: 0.7380877312611555 and parameters: {'long_window': 395, 'short_window': 121}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:46:08,127] Trial 26 finished with value: 0.7523384577529973 and parameters: {'long_window': 463, 'short_window': 31}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:46:11,184] Trial 27 finished with value: 0.761736274243365 and parameters: {'long_window': 401, 'short_window': 82}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:46:14,231] Trial 28 finished with value: 0.7019892787196705 and parameters: {'long_window': 343, 'short_window': 164}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:46:17,298] Trial 29 finished with value: 0.6140138923494622 and parameters: {'long_window': 202, 'short_window': 119}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:46:20,354] Trial 30 finished with value: 0.7092877988209917 and parameters: {'long_window': 261, 'short_window': 68}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:46:23,420] Trial 31 finished with value: 0.7493555790035202 and parameters: {'long_window': 349, 'short_window': 94}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:46:26,469] Trial 32 finished with value: 0.7449753524635203 and parameters: {'long_window': 367, 'short_window': 93}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:46:29,506] Trial 33 finished with value: 0.7248621695931048 and parameters: {'long_window': 296, 'short_window': 61}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:46:32,577] Trial 34 finished with value: 0.7402127733483825 and parameters: {'long_window': 237, 'short_window': 130}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:46:35,603] Trial 35 finished with value: 0.7324181468354726 and parameters: {'long_window': 419, 'short_window': 39}. Best is trial 12 with value: 0.7992672178740159.
# [I 2025-03-02 20:46:38,609] Trial 36 finished with value: 0.8037043249310463 and parameters: {'long_window': 500, 'short_window': 84}. Best is trial 36 with value: 0.8037043249310463.
# [I 2025-03-02 20:46:42,059] Trial 37 finished with value: 0.6762963829952223 and parameters: {'long_window': 470, 'short_window': 210}. Best is trial 36 with value: 0.8037043249310463.
# [I 2025-03-02 20:46:45,092] Trial 38 finished with value: 0.7597682147464192 and parameters: {'long_window': 495, 'short_window': 21}. Best is trial 36 with value: 0.8037043249310463.
# [I 2025-03-02 20:46:48,128] Trial 39 finished with value: 0.8010580116287863 and parameters: {'long_window': 457, 'short_window': 50}. Best is trial 36 with value: 0.8037043249310463.
# [I 2025-03-02 20:46:51,150] Trial 40 finished with value: 0.8018898639669517 and parameters: {'long_window': 457, 'short_window': 47}. Best is trial 36 with value: 0.8037043249310463.
# [I 2025-03-02 20:46:54,192] Trial 41 finished with value: 0.7462320414914047 and parameters: {'long_window': 464, 'short_window': 48}. Best is trial 36 with value: 0.8037043249310463.
# [I 2025-03-02 20:46:57,224] Trial 42 finished with value: 0.755600260814595 and parameters: {'long_window': 442, 'short_window': 51}. Best is trial 36 with value: 0.8037043249310463.
# [I 2025-03-02 20:47:00,243] Trial 43 finished with value: 0.7833675382501679 and parameters: {'long_window': 473, 'short_window': 24}. Best is trial 36 with value: 0.8037043249310463.
# [I 2025-03-02 20:47:03,241] Trial 44 finished with value: 0.8075182258044974 and parameters: {'long_window': 500, 'short_window': 63}. Best is trial 44 with value: 0.8075182258044974.
# [I 2025-03-02 20:47:06,271] Trial 45 finished with value: 0.8189382233967791 and parameters: {'long_window': 500, 'short_window': 57}. Best is trial 45 with value: 0.8189382233967791.
# [I 2025-03-02 20:47:09,280] Trial 46 finished with value: 0.8075182258044974 and parameters: {'long_window': 500, 'short_window': 60}. Best is trial 45 with value: 0.8189382233967791.
# [I 2025-03-02 20:47:12,295] Trial 47 finished with value: 0.7865649136678294 and parameters: {'long_window': 497, 'short_window': 60}. Best is trial 45 with value: 0.8189382233967791.
# [I 2025-03-02 20:47:15,347] Trial 48 finished with value: 0.8041485362290364 and parameters: {'long_window': 413, 'short_window': 60}. Best is trial 45 with value: 0.8189382233967791.
# [I 2025-03-02 20:47:18,382] Trial 49 finished with value: 0.755357297253751 and parameters: {'long_window': 420, 'short_window': 39}. Best is trial 45 with value: 0.8189382233967791.
# [I 2025-03-02 20:47:18,604] A new study created in memory with name: no-name-a4c34bf1-28cc-45b8-8ffa-6872a78d46f8
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-03-02 20:47:18,611] Trial 0 finished with value: -1.0 and parameters: {'long_window': 218, 'short_window': 240}. Best is trial 0 with value: -1.0.
# [I 2025-03-02 20:47:21,997] Trial 1 finished with value: 0.7145515003551968 and parameters: {'long_window': 380, 'short_window': 153}. Best is trial 1 with value: 0.7145515003551968.
# [I 2025-03-02 20:47:25,406] Trial 2 finished with value: 0.6628389096241762 and parameters: {'long_window': 120, 'short_window': 43}. Best is trial 1 with value: 0.7145515003551968.
# [I 2025-03-02 20:47:25,408] Trial 3 finished with value: -1.0 and parameters: {'long_window': 76, 'short_window': 219}. Best is trial 1 with value: 0.7145515003551968.
# [I 2025-03-02 20:47:28,800] Trial 4 finished with value: 0.7507434134870788 and parameters: {'long_window': 321, 'short_window': 180}. Best is trial 4 with value: 0.7507434134870788.
# [I 2025-03-02 20:47:28,802] Trial 5 finished with value: -1.0 and parameters: {'long_window': 59, 'short_window': 245}. Best is trial 4 with value: 0.7507434134870788.
# [I 2025-03-02 20:47:32,173] Trial 6 finished with value: 0.7025853121013075 and parameters: {'long_window': 425, 'short_window': 57}. Best is trial 4 with value: 0.7507434134870788.
# [I 2025-03-02 20:47:35,597] Trial 7 finished with value: 0.493720026343728 and parameters: {'long_window': 132, 'short_window': 50}. Best is trial 4 with value: 0.7507434134870788.
# [I 2025-03-02 20:47:39,008] Trial 8 finished with value: 0.7073394795999879 and parameters: {'long_window': 187, 'short_window': 135}. Best is trial 4 with value: 0.7507434134870788.
# [I 2025-03-02 20:47:42,461] Trial 9 finished with value: 0.6584248629036762 and parameters: {'long_window': 244, 'short_window': 77}. Best is trial 4 with value: 0.7507434134870788.
# [I 2025-03-02 20:47:45,868] Trial 10 finished with value: 0.7477981343960436 and parameters: {'long_window': 335, 'short_window': 183}. Best is trial 4 with value: 0.7507434134870788.
# [I 2025-03-02 20:47:49,279] Trial 11 finished with value: 0.7590493638136194 and parameters: {'long_window': 317, 'short_window': 183}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-02 20:47:52,737] Trial 12 finished with value: 0.757027256502465 and parameters: {'long_window': 312, 'short_window': 186}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-02 20:47:56,156] Trial 13 finished with value: 0.7365251942265324 and parameters: {'long_window': 469, 'short_window': 102}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-02 20:47:59,546] Trial 14 finished with value: 0.7071848075595291 and parameters: {'long_window': 296, 'short_window': 8}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-02 20:48:03,336] Trial 15 finished with value: 0.7430303607425243 and parameters: {'long_window': 373, 'short_window': 197}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-02 20:48:06,752] Trial 16 finished with value: 0.7565051847385534 and parameters: {'long_window': 274, 'short_window': 155}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-02 20:48:10,142] Trial 17 finished with value: 0.6603293776552821 and parameters: {'long_window': 491, 'short_window': 208}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-02 20:48:13,520] Trial 18 finished with value: 0.7137412211007343 and parameters: {'long_window': 373, 'short_window': 120}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-02 20:48:16,900] Trial 19 finished with value: 0.7475613629018939 and parameters: {'long_window': 431, 'short_window': 165}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-02 20:48:16,912] Trial 20 finished with value: -1.0 and parameters: {'long_window': 194, 'short_window': 223}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-02 20:48:20,324] Trial 21 finished with value: 0.734500581200136 and parameters: {'long_window': 261, 'short_window': 148}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-02 20:48:23,745] Trial 22 finished with value: 0.7454955131865812 and parameters: {'long_window': 293, 'short_window': 166}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-02 20:48:27,156] Trial 23 finished with value: 0.7406783297621615 and parameters: {'long_window': 341, 'short_window': 116}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-02 20:48:30,609] Trial 24 finished with value: 0.7431881323373638 and parameters: {'long_window': 247, 'short_window': 179}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-02 20:48:34,062] Trial 25 finished with value: 0.7239231453544485 and parameters: {'long_window': 289, 'short_window': 195}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-02 20:48:37,506] Trial 26 finished with value: 0.6102153935100674 and parameters: {'long_window': 210, 'short_window': 139}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-02 20:48:40,891] Trial 27 finished with value: 0.752842895963603 and parameters: {'long_window': 404, 'short_window': 103}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-02 20:48:44,327] Trial 28 finished with value: 0.7147522890386014 and parameters: {'long_window': 309, 'short_window': 163}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-02 20:48:44,342] Trial 29 finished with value: -1.0 and parameters: {'long_window': 158, 'short_window': 230}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-02 20:48:47,777] Trial 30 finished with value: 0.7299679087980414 and parameters: {'long_window': 236, 'short_window': 208}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-02 20:48:51,155] Trial 31 finished with value: 0.7387068583151506 and parameters: {'long_window': 402, 'short_window': 91}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-02 20:48:54,567] Trial 32 finished with value: 0.7725293794014212 and parameters: {'long_window': 356, 'short_window': 122}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-02 20:48:57,948] Trial 33 finished with value: 0.7252561363214008 and parameters: {'long_window': 344, 'short_window': 151}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-02 20:49:01,349] Trial 34 finished with value: 0.714033939386895 and parameters: {'long_window': 268, 'short_window': 137}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-02 20:49:04,729] Trial 35 finished with value: 0.6950911802068954 and parameters: {'long_window': 369, 'short_window': 120}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-02 20:49:08,120] Trial 36 finished with value: 0.7586304129009177 and parameters: {'long_window': 322, 'short_window': 178}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-02 20:49:11,584] Trial 37 finished with value: 0.7677112929466264 and parameters: {'long_window': 327, 'short_window': 192}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-02 20:49:14,989] Trial 38 finished with value: 0.7057810321278077 and parameters: {'long_window': 349, 'short_window': 248}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-02 20:49:18,374] Trial 39 finished with value: 0.7190263446339167 and parameters: {'long_window': 395, 'short_window': 231}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-02 20:49:21,748] Trial 40 finished with value: 0.7285565182414229 and parameters: {'long_window': 420, 'short_window': 209}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-02 20:49:25,166] Trial 41 finished with value: 0.7632069421328008 and parameters: {'long_window': 325, 'short_window': 186}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-02 20:49:28,974] Trial 42 finished with value: 0.7279692179185736 and parameters: {'long_window': 360, 'short_window': 172}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-02 20:49:32,423] Trial 43 finished with value: 0.7360055149852819 and parameters: {'long_window': 317, 'short_window': 191}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-02 20:49:35,836] Trial 44 finished with value: 0.777632463725657 and parameters: {'long_window': 331, 'short_window': 201}. Best is trial 44 with value: 0.777632463725657.
# [I 2025-03-02 20:49:39,231] Trial 45 finished with value: 0.7612774583917752 and parameters: {'long_window': 326, 'short_window': 203}. Best is trial 44 with value: 0.777632463725657.
# [I 2025-03-02 20:49:42,627] Trial 46 finished with value: 0.7037871317791564 and parameters: {'long_window': 444, 'short_window': 216}. Best is trial 44 with value: 0.777632463725657.
# [I 2025-03-02 20:49:46,022] Trial 47 finished with value: 0.696022840992405 and parameters: {'long_window': 388, 'short_window': 236}. Best is trial 44 with value: 0.777632463725657.
# [I 2025-03-02 20:49:49,417] Trial 48 finished with value: 0.7159253275815567 and parameters: {'long_window': 337, 'short_window': 197}. Best is trial 44 with value: 0.777632463725657.
# [I 2025-03-02 20:49:52,816] Trial 49 finished with value: 0.6254677461313783 and parameters: {'long_window': 293, 'short_window': 61}. Best is trial 44 with value: 0.777632463725657.

# %% [markdown]
# ## Results

# %%
start_date = None
end_date = None
for method in returns_logs:
    df = returns_logs[method].copy()

    if start_date is None:
        start_date = df.index[0]
    if end_date is None:
        end_date = df.index[-1]
    if df.index[0] > start_date:
        start_date = df.index[0]
    if df.index[-1] < end_date:
        end_date = df.index[-1]

print(start_date, end_date)
plt.figure(figsize=(20, 6))
for method in returns_logs:
    df = returns_logs[method].copy()
    df = df.loc[start_date:end_date]
    df['cumulative_returns'] = (1 + df['returns']).cumprod()
    cagr = (df['cumulative_returns'][-1] ** (252 / len(df))) - 1
    vol = df['returns'].std() * np.sqrt(252)
    sharpe_ratio = cagr / vol

    print(f'{method}\n CAGR: {cagr:.4f}\n Volatility: {vol:.4f}\n Sharpe Ratio: {sharpe_ratio:.4f}')
    
    plt.plot(df['cumulative_returns'], label=f'{method}')
plt.xlabel('Date')
plt.ylabel('Cumulative Returns')
plt.yscale('log')
plt.legend()
plt.show()
# Out:
# 2000-04-11 00:00:00 2025-02-28 00:00:00
# buy_hold
#  CAGR: 0.0760
#  Volatility: 0.1933
#  Sharpe Ratio: 0.3932
# ma_cross_reference
#  CAGR: 0.0810
#  Volatility: 0.1307
#  Sharpe Ratio: 0.6193
# ma_cross_oracle
#  CAGR: 0.0833
#  Volatility: 0.1437
#  Sharpe Ratio: 0.5796
# ma_cross_prior_opt_5
#  CAGR: 0.0633
#  Volatility: 0.1285
#  Sharpe Ratio: 0.4927
# ma_cross_prior_opt_10
#  CAGR: 0.0545
#  Volatility: 0.1427
#  Sharpe Ratio: 0.3820

# %% [markdown]
# Optimization for long_window and short_window using historical data produces worse results. This suggests that there are regime changes throughout the time series. The parameter are optimized for the previous regime and hence are overfitted and perform worse in the new regime.

# %% [markdown]
# # Parameters for prior period optimization

# %%
from sklearn.model_selection import TimeSeriesSplit
# Initialize TimeSeriesSplit


def find_parameters(ticker, df, n_splits=5, n_trials=100, verbose=False):
    tscv = TimeSeriesSplit(n_splits=n_splits)
    
    df_output = df.copy()
    df_output['short_window'] = 0
    df_output['long_wwindow'] = 0

    params_pairs = []

    # Perform cross-validation splits
    for train_index, test_index in tscv.split(df):
        train = df.iloc[train_index]
        test = df.iloc[test_index]

        # Fit the model on the training set
        best_params = optimize_params(ticker, train, n_trials)

        df_output.loc[df_output.index.isin(train.index), 'short_window'] = best_params['short_window']
        df_output.loc[df_output.index.isin(train.index), 'long_window'] = best_params['long_window']

        params_pairs.append(best_params)
    
    return df_output[['short_window', 'long_window']], params_pairs

ticker = 'SPY'
df_data = price_data[ticker]

for i in [5, 10, 20]:
    df, param_pairs = find_parameters(ticker, df_data, n_splits=i, n_trials=50)

    # plt.plot(df.index, df['short_window'], label='Short Window')
    # plt.plot(df.index, df['long_window'], label='Long Window')
    # plt.title(f'{ticker} - {i} Splits')
    # plt.xlabel('Date')
    # plt.ylabel('Window Size')
    # plt.legend()

    long_windows = [f['long_window'] for f in param_pairs]
    short_windows = [f['short_window'] for f in param_pairs]

    plt.scatter(long_windows, short_windows, alpha=0.5, label=f'{i} Splits')

plt.xlabel('Long Window')
plt.ylabel('Short Window')
plt.legend()
plt.show()
# Out:
# [I 2025-03-02 23:52:20,852] A new study created in memory with name: no-name-f351dd31-410e-43a2-8bb2-aaac51270b69
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-03-02 23:52:20,860] Trial 0 finished with value: -1.0 and parameters: {'long_window': 218, 'short_window': 240}. Best is trial 0 with value: -1.0.
# [I 2025-03-02 23:52:21,411] Trial 1 finished with value: 1.8809612392365953 and parameters: {'long_window': 380, 'short_window': 153}. Best is trial 1 with value: 1.8809612392365953.
# [I 2025-03-02 23:52:22,015] Trial 2 finished with value: 1.4282293898786864 and parameters: {'long_window': 120, 'short_window': 43}. Best is trial 1 with value: 1.8809612392365953.
# [I 2025-03-02 23:52:22,017] Trial 3 finished with value: -1.0 and parameters: {'long_window': 76, 'short_window': 219}. Best is trial 1 with value: 1.8809612392365953.
# [I 2025-03-02 23:52:22,566] Trial 4 finished with value: 1.8025861710834405 and parameters: {'long_window': 321, 'short_window': 180}. Best is trial 1 with value: 1.8809612392365953.
# [I 2025-03-02 23:52:22,568] Trial 5 finished with value: -1.0 and parameters: {'long_window': 59, 'short_window': 245}. Best is trial 1 with value: 1.8809612392365953.
# [I 2025-03-02 23:52:23,096] Trial 6 finished with value: 2.037698028770274 and parameters: {'long_window': 425, 'short_window': 57}. Best is trial 6 with value: 2.037698028770274.
# [I 2025-03-02 23:52:23,702] Trial 7 finished with value: 1.3850005888142385 and parameters: {'long_window': 132, 'short_window': 50}. Best is trial 6 with value: 2.037698028770274.
# [I 2025-03-02 23:52:24,285] Trial 8 finished with value: 1.6710666495171804 and parameters: {'long_window': 187, 'short_window': 135}. Best is trial 6 with value: 2.037698028770274.
# [I 2025-03-02 23:52:24,852] Trial 9 finished with value: 1.6755414185922601 and parameters: {'long_window': 244, 'short_window': 77}. Best is trial 6 with value: 2.037698028770274.
# [I 2025-03-02 23:52:25,362] Trial 10 finished with value: 2.1113701465760912 and parameters: {'long_window': 491, 'short_window': 6}. Best is trial 10 with value: 2.1113701465760912.
# [I 2025-03-02 23:52:25,891] Trial 11 finished with value: 2.117767885729392 and parameters: {'long_window': 487, 'short_window': 6}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 23:52:26,404] Trial 12 finished with value: 2.0821836051338436 and parameters: {'long_window': 496, 'short_window': 12}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 23:52:26,915] Trial 13 finished with value: 2.1062644561877657 and parameters: {'long_window': 494, 'short_window': 6}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 23:52:27,450] Trial 14 finished with value: 1.9229535203854589 and parameters: {'long_window': 411, 'short_window': 99}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 23:52:28,001] Trial 15 finished with value: 1.8099120245142013 and parameters: {'long_window': 348, 'short_window': 101}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 23:52:28,524] Trial 16 finished with value: 1.9384173978229438 and parameters: {'long_window': 453, 'short_window': 30}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 23:52:29,084] Trial 17 finished with value: 1.8190555174873893 and parameters: {'long_window': 321, 'short_window': 83}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 23:52:29,612] Trial 18 finished with value: 1.968434416112611 and parameters: {'long_window': 456, 'short_window': 6}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 23:52:30,179] Trial 19 finished with value: 1.502462131809011 and parameters: {'long_window': 283, 'short_window': 31}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 23:52:30,726] Trial 20 finished with value: 1.8625352674451778 and parameters: {'long_window': 387, 'short_window': 176}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 23:52:31,247] Trial 21 finished with value: 2.090694988652949 and parameters: {'long_window': 498, 'short_window': 9}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 23:52:31,775] Trial 22 finished with value: 2.023850048473789 and parameters: {'long_window': 470, 'short_window': 29}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 23:52:32,325] Trial 23 finished with value: 1.9793652170362905 and parameters: {'long_window': 419, 'short_window': 60}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 23:52:32,872] Trial 24 finished with value: 2.079199668070158 and parameters: {'long_window': 497, 'short_window': 5}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 23:52:33,411] Trial 25 finished with value: 1.9828295631131836 and parameters: {'long_window': 447, 'short_window': 74}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 23:52:33,988] Trial 26 finished with value: 1.8018310971687095 and parameters: {'long_window': 372, 'short_window': 36}. Best is trial 11 with value: 2.117767885729392.
# [I 2025-03-02 23:52:34,528] Trial 27 finished with value: 2.1236824187362147 and parameters: {'long_window': 475, 'short_window': 111}. Best is trial 27 with value: 2.1236824187362147.
# [I 2025-03-02 23:52:35,108] Trial 28 finished with value: 2.042865134303952 and parameters: {'long_window': 427, 'short_window': 120}. Best is trial 27 with value: 2.1236824187362147.
# [I 2025-03-02 23:52:35,658] Trial 29 finished with value: 2.1152589038764096 and parameters: {'long_window': 467, 'short_window': 223}. Best is trial 27 with value: 2.1236824187362147.
# [I 2025-03-02 23:52:36,254] Trial 30 finished with value: 1.6237366130062523 and parameters: {'long_window': 343, 'short_window': 216}. Best is trial 27 with value: 2.1236824187362147.
# [I 2025-03-02 23:52:36,801] Trial 31 finished with value: 2.1152589038764096 and parameters: {'long_window': 467, 'short_window': 183}. Best is trial 27 with value: 2.1236824187362147.
# [I 2025-03-02 23:52:37,354] Trial 32 finished with value: 1.7172297180096643 and parameters: {'long_window': 390, 'short_window': 219}. Best is trial 27 with value: 2.1236824187362147.
# [I 2025-03-02 23:52:37,934] Trial 33 finished with value: 2.1374426796247747 and parameters: {'long_window': 460, 'short_window': 195}. Best is trial 33 with value: 2.1374426796247747.
# [I 2025-03-02 23:52:38,475] Trial 34 finished with value: 1.8907473334798999 and parameters: {'long_window': 434, 'short_window': 199}. Best is trial 33 with value: 2.1374426796247747.
# [I 2025-03-02 23:52:39,029] Trial 35 finished with value: 1.6810900662620132 and parameters: {'long_window': 402, 'short_window': 231}. Best is trial 33 with value: 2.1374426796247747.
# [I 2025-03-02 23:52:39,570] Trial 36 finished with value: 2.128071759620883 and parameters: {'long_window': 470, 'short_window': 153}. Best is trial 33 with value: 2.1374426796247747.
# [I 2025-03-02 23:52:40,132] Trial 37 finished with value: 1.9181022213443213 and parameters: {'long_window': 368, 'short_window': 157}. Best is trial 33 with value: 2.1374426796247747.
# [I 2025-03-02 23:52:40,739] Trial 38 finished with value: 1.666004728478677 and parameters: {'long_window': 189, 'short_window': 153}. Best is trial 33 with value: 2.1374426796247747.
# [I 2025-03-02 23:52:41,316] Trial 39 finished with value: 1.836701148058023 and parameters: {'long_window': 293, 'short_window': 136}. Best is trial 33 with value: 2.1374426796247747.
# [I 2025-03-02 23:52:41,861] Trial 40 finished with value: 1.948979105870827 and parameters: {'long_window': 442, 'short_window': 168}. Best is trial 33 with value: 2.1374426796247747.
# [I 2025-03-02 23:52:42,399] Trial 41 finished with value: 2.032144458319291 and parameters: {'long_window': 467, 'short_window': 198}. Best is trial 33 with value: 2.1374426796247747.
# [I 2025-03-02 23:52:42,949] Trial 42 finished with value: 2.1688743201021254 and parameters: {'long_window': 471, 'short_window': 236}. Best is trial 42 with value: 2.1688743201021254.
# [I 2025-03-02 23:52:43,484] Trial 43 finished with value: 2.1486444061922767 and parameters: {'long_window': 473, 'short_window': 126}. Best is trial 42 with value: 2.1688743201021254.
# [I 2025-03-02 23:52:44,040] Trial 44 finished with value: 1.9756630275491536 and parameters: {'long_window': 430, 'short_window': 118}. Best is trial 42 with value: 2.1688743201021254.
# [I 2025-03-02 23:52:44,578] Trial 45 finished with value: 2.142123287398858 and parameters: {'long_window': 474, 'short_window': 248}. Best is trial 42 with value: 2.1688743201021254.
# [I 2025-03-02 23:52:45,127] Trial 46 finished with value: 1.7720333157823853 and parameters: {'long_window': 404, 'short_window': 244}. Best is trial 42 with value: 2.1688743201021254.
# [I 2025-03-02 23:52:45,674] Trial 47 finished with value: 1.8317869993622042 and parameters: {'long_window': 444, 'short_window': 200}. Best is trial 42 with value: 2.1688743201021254.
# [I 2025-03-02 23:52:45,692] Trial 48 finished with value: -1.0 and parameters: {'long_window': 103, 'short_window': 249}. Best is trial 42 with value: 2.1688743201021254.
# [I 2025-03-02 23:52:46,290] A new study created in memory with name: no-name-99186da9-ef48-4200-ad42-f82b8f5bb6d1
# [I 2025-03-02 23:52:46,284] Trial 49 finished with value: 1.6717986870045356 and parameters: {'long_window': 231, 'short_window': 143}. Best is trial 42 with value: 2.1688743201021254.
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-03-02 23:52:46,298] Trial 0 finished with value: -1.0 and parameters: {'long_window': 218, 'short_window': 240}. Best is trial 0 with value: -1.0.
# [I 2025-03-02 23:52:47,539] Trial 1 finished with value: 0.8320419679114547 and parameters: {'long_window': 380, 'short_window': 153}. Best is trial 1 with value: 0.8320419679114547.
# [I 2025-03-02 23:52:48,836] Trial 2 finished with value: 0.6243271283554286 and parameters: {'long_window': 120, 'short_window': 43}. Best is trial 1 with value: 0.8320419679114547.
# [I 2025-03-02 23:52:48,838] Trial 3 finished with value: -1.0 and parameters: {'long_window': 76, 'short_window': 219}. Best is trial 1 with value: 0.8320419679114547.
# [I 2025-03-02 23:52:50,033] Trial 4 finished with value: 0.8754914791304916 and parameters: {'long_window': 321, 'short_window': 180}. Best is trial 4 with value: 0.8754914791304916.
# [I 2025-03-02 23:52:50,036] Trial 5 finished with value: -1.0 and parameters: {'long_window': 59, 'short_window': 245}. Best is trial 4 with value: 0.8754914791304916.
# [I 2025-03-02 23:52:51,257] Trial 6 finished with value: 0.9775378996792822 and parameters: {'long_window': 425, 'short_window': 57}. Best is trial 6 with value: 0.9775378996792822.
# [I 2025-03-02 23:52:52,509] Trial 7 finished with value: 0.47368399553366164 and parameters: {'long_window': 132, 'short_window': 50}. Best is trial 6 with value: 0.9775378996792822.
# [I 2025-03-02 23:52:53,746] Trial 8 finished with value: 0.8084688610829058 and parameters: {'long_window': 187, 'short_window': 135}. Best is trial 6 with value: 0.9775378996792822.
# [I 2025-03-02 23:52:54,957] Trial 9 finished with value: 0.839472498866702 and parameters: {'long_window': 244, 'short_window': 77}. Best is trial 6 with value: 0.9775378996792822.
# [I 2025-03-02 23:52:56,117] Trial 10 finished with value: 0.9362910267543566 and parameters: {'long_window': 491, 'short_window': 6}. Best is trial 6 with value: 0.9775378996792822.
# [I 2025-03-02 23:52:57,273] Trial 11 finished with value: 0.9537763874437132 and parameters: {'long_window': 487, 'short_window': 6}. Best is trial 6 with value: 0.9775378996792822.
# [I 2025-03-02 23:52:58,448] Trial 12 finished with value: 0.9178621097234415 and parameters: {'long_window': 493, 'short_window': 90}. Best is trial 6 with value: 0.9775378996792822.
# [I 2025-03-02 23:52:59,647] Trial 13 finished with value: 0.9856785397826411 and parameters: {'long_window': 419, 'short_window': 8}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:00,845] Trial 14 finished with value: 0.9101792789793332 and parameters: {'long_window': 403, 'short_window': 99}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:02,022] Trial 15 finished with value: 0.9280741092372212 and parameters: {'long_window': 413, 'short_window': 40}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:03,237] Trial 16 finished with value: 0.8767457356355979 and parameters: {'long_window': 311, 'short_window': 55}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:04,440] Trial 17 finished with value: 0.9187783188017828 and parameters: {'long_window': 353, 'short_window': 24}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:05,636] Trial 18 finished with value: 0.9287679076894548 and parameters: {'long_window': 440, 'short_window': 108}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:06,805] Trial 19 finished with value: 0.935906583782433 and parameters: {'long_window': 437, 'short_window': 66}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:08,019] Trial 20 finished with value: 0.7700837319077004 and parameters: {'long_window': 282, 'short_window': 22}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:09,175] Trial 21 finished with value: 0.9763532374481466 and parameters: {'long_window': 466, 'short_window': 10}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:10,341] Trial 22 finished with value: 0.9701869726389842 and parameters: {'long_window': 439, 'short_window': 29}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:11,529] Trial 23 finished with value: 0.8907319991616296 and parameters: {'long_window': 367, 'short_window': 7}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:12,691] Trial 24 finished with value: 0.953771209943841 and parameters: {'long_window': 466, 'short_window': 79}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:13,876] Trial 25 finished with value: 0.85975350640549 and parameters: {'long_window': 338, 'short_window': 60}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:15,116] Trial 26 finished with value: 0.8928751593414426 and parameters: {'long_window': 387, 'short_window': 120}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:16,318] Trial 27 finished with value: 0.9781277985877687 and parameters: {'long_window': 455, 'short_window': 28}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:17,538] Trial 28 finished with value: 0.878421992087599 and parameters: {'long_window': 296, 'short_window': 30}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:18,734] Trial 29 finished with value: 0.8926110285134041 and parameters: {'long_window': 414, 'short_window': 70}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:19,991] Trial 30 finished with value: 0.8310025687747405 and parameters: {'long_window': 242, 'short_window': 166}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:21,182] Trial 31 finished with value: 0.936537168371752 and parameters: {'long_window': 459, 'short_window': 20}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:22,360] Trial 32 finished with value: 0.9506283928289215 and parameters: {'long_window': 469, 'short_window': 38}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:23,553] Trial 33 finished with value: 0.9805437459490001 and parameters: {'long_window': 426, 'short_window': 17}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:24,761] Trial 34 finished with value: 0.9057240587568648 and parameters: {'long_window': 389, 'short_window': 44}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:25,955] Trial 35 finished with value: 0.7575426637470882 and parameters: {'long_window': 417, 'short_window': 219}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:27,151] Trial 36 finished with value: 0.8979805234673846 and parameters: {'long_window': 360, 'short_window': 50}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:28,327] Trial 37 finished with value: 0.9291914197318475 and parameters: {'long_window': 437, 'short_window': 20}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:29,591] Trial 38 finished with value: 0.7599802229508786 and parameters: {'long_window': 189, 'short_window': 35}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:30,801] Trial 39 finished with value: 0.878279264196057 and parameters: {'long_window': 333, 'short_window': 87}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:32,079] Trial 40 finished with value: 0.7126211975758336 and parameters: {'long_window': 383, 'short_window': 204}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:33,334] Trial 41 finished with value: 0.9535842648620376 and parameters: {'long_window': 459, 'short_window': 17}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:34,549] Trial 42 finished with value: 0.9230480199106506 and parameters: {'long_window': 480, 'short_window': 6}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:35,756] Trial 43 finished with value: 0.9703403949765081 and parameters: {'long_window': 427, 'short_window': 15}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:36,949] Trial 44 finished with value: 0.9581206882012597 and parameters: {'long_window': 500, 'short_window': 51}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:38,145] Trial 45 finished with value: 0.9268933015559078 and parameters: {'long_window': 452, 'short_window': 36}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:39,368] Trial 46 finished with value: 0.924112735293918 and parameters: {'long_window': 405, 'short_window': 13}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:40,558] Trial 47 finished with value: 0.9384358677752324 and parameters: {'long_window': 481, 'short_window': 29}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:40,576] Trial 48 finished with value: -1.0 and parameters: {'long_window': 103, 'short_window': 133}. Best is trial 13 with value: 0.9856785397826411.
# [I 2025-03-02 23:53:41,784] A new study created in memory with name: no-name-833604e3-fb9f-43f7-9f17-7eb10fc3587c
# [I 2025-03-02 23:53:41,779] Trial 49 finished with value: 0.9508668984167946 and parameters: {'long_window': 392, 'short_window': 61}. Best is trial 13 with value: 0.9856785397826411.
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-03-02 23:53:41,792] Trial 0 finished with value: -1.0 and parameters: {'long_window': 218, 'short_window': 240}. Best is trial 0 with value: -1.0.
# [I 2025-03-02 23:53:43,686] Trial 1 finished with value: 0.7520123629646583 and parameters: {'long_window': 380, 'short_window': 153}. Best is trial 1 with value: 0.7520123629646583.
# [I 2025-03-02 23:53:45,606] Trial 2 finished with value: 0.594198544918815 and parameters: {'long_window': 120, 'short_window': 43}. Best is trial 1 with value: 0.7520123629646583.
# [I 2025-03-02 23:53:45,610] Trial 3 finished with value: -1.0 and parameters: {'long_window': 76, 'short_window': 219}. Best is trial 1 with value: 0.7520123629646583.
# [I 2025-03-02 23:53:47,502] Trial 4 finished with value: 0.7692314654179755 and parameters: {'long_window': 321, 'short_window': 180}. Best is trial 4 with value: 0.7692314654179755.
# [I 2025-03-02 23:53:47,504] Trial 5 finished with value: -1.0 and parameters: {'long_window': 59, 'short_window': 245}. Best is trial 4 with value: 0.7692314654179755.
# [I 2025-03-02 23:53:49,353] Trial 6 finished with value: 0.8244370500503972 and parameters: {'long_window': 425, 'short_window': 57}. Best is trial 6 with value: 0.8244370500503972.
# [I 2025-03-02 23:53:51,367] Trial 7 finished with value: 0.4526114074834083 and parameters: {'long_window': 132, 'short_window': 50}. Best is trial 6 with value: 0.8244370500503972.
# [I 2025-03-02 23:53:53,704] Trial 8 finished with value: 0.7502306234536907 and parameters: {'long_window': 187, 'short_window': 135}. Best is trial 6 with value: 0.8244370500503972.
# [I 2025-03-02 23:53:55,585] Trial 9 finished with value: 0.7299529046996923 and parameters: {'long_window': 244, 'short_window': 77}. Best is trial 6 with value: 0.8244370500503972.
# [I 2025-03-02 23:53:57,420] Trial 10 finished with value: 0.8200366603458198 and parameters: {'long_window': 491, 'short_window': 6}. Best is trial 6 with value: 0.8244370500503972.
# [I 2025-03-02 23:53:59,279] Trial 11 finished with value: 0.8139479164105892 and parameters: {'long_window': 487, 'short_window': 6}. Best is trial 6 with value: 0.8244370500503972.
# [I 2025-03-02 23:54:01,116] Trial 12 finished with value: 0.7747396327172692 and parameters: {'long_window': 493, 'short_window': 90}. Best is trial 6 with value: 0.8244370500503972.
# [I 2025-03-02 23:54:02,975] Trial 13 finished with value: 0.8470241793285519 and parameters: {'long_window': 419, 'short_window': 8}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 23:54:04,851] Trial 14 finished with value: 0.7774959320094469 and parameters: {'long_window': 403, 'short_window': 99}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 23:54:06,734] Trial 15 finished with value: 0.8130154367611737 and parameters: {'long_window': 413, 'short_window': 40}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 23:54:08,603] Trial 16 finished with value: 0.7771861001449049 and parameters: {'long_window': 311, 'short_window': 55}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 23:54:10,522] Trial 17 finished with value: 0.8045630406167217 and parameters: {'long_window': 353, 'short_window': 24}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 23:54:12,406] Trial 18 finished with value: 0.8118949197143817 and parameters: {'long_window': 440, 'short_window': 108}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 23:54:14,275] Trial 19 finished with value: 0.8274564843210699 and parameters: {'long_window': 437, 'short_window': 66}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 23:54:16,150] Trial 20 finished with value: 0.7938934630993069 and parameters: {'long_window': 287, 'short_window': 74}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 23:54:17,990] Trial 21 finished with value: 0.8266941503363237 and parameters: {'long_window': 429, 'short_window': 20}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 23:54:19,816] Trial 22 finished with value: 0.8032801311618897 and parameters: {'long_window': 451, 'short_window': 28}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 23:54:21,665] Trial 23 finished with value: 0.829311863022629 and parameters: {'long_window': 376, 'short_window': 21}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 23:54:23,500] Trial 24 finished with value: 0.7692091548405354 and parameters: {'long_window': 363, 'short_window': 72}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 23:54:25,351] Trial 25 finished with value: 0.8223167826867335 and parameters: {'long_window': 340, 'short_window': 6}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 23:54:27,187] Trial 26 finished with value: 0.8055918378285087 and parameters: {'long_window': 389, 'short_window': 31}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 23:54:29,047] Trial 27 finished with value: 0.7807774277730928 and parameters: {'long_window': 462, 'short_window': 119}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 23:54:30,965] Trial 28 finished with value: 0.8052155807162271 and parameters: {'long_window': 296, 'short_window': 60}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 23:54:32,850] Trial 29 finished with value: 0.7892589559538128 and parameters: {'long_window': 270, 'short_window': 83}. Best is trial 13 with value: 0.8470241793285519.
# [I 2025-03-02 23:54:34,696] Trial 30 finished with value: 0.8472206142703675 and parameters: {'long_window': 375, 'short_window': 23}. Best is trial 30 with value: 0.8472206142703675.
# [I 2025-03-02 23:54:36,555] Trial 31 finished with value: 0.8550809811155904 and parameters: {'long_window': 379, 'short_window': 20}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 23:54:38,390] Trial 32 finished with value: 0.829311863022629 and parameters: {'long_window': 376, 'short_window': 20}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 23:54:40,226] Trial 33 finished with value: 0.810047356489802 and parameters: {'long_window': 402, 'short_window': 38}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 23:54:42,078] Trial 34 finished with value: 0.7321804299915521 and parameters: {'long_window': 334, 'short_window': 186}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 23:54:43,931] Trial 35 finished with value: 0.7765290963078701 and parameters: {'long_window': 371, 'short_window': 16}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 23:54:45,790] Trial 36 finished with value: 0.6820230476213853 and parameters: {'long_window': 262, 'short_window': 44}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 23:54:47,668] Trial 37 finished with value: 0.7014626020813808 and parameters: {'long_window': 464, 'short_window': 163}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 23:54:47,686] Trial 38 finished with value: -1.0 and parameters: {'long_window': 189, 'short_window': 212}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 23:54:49,519] Trial 39 finished with value: 0.770200646624099 and parameters: {'long_window': 320, 'short_window': 35}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 23:54:51,362] Trial 40 finished with value: 0.8165279178226899 and parameters: {'long_window': 393, 'short_window': 52}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 23:54:53,187] Trial 41 finished with value: 0.815138216677231 and parameters: {'long_window': 377, 'short_window': 20}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 23:54:55,009] Trial 42 finished with value: 0.8192137651723559 and parameters: {'long_window': 369, 'short_window': 16}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 23:54:56,834] Trial 43 finished with value: 0.8359752994095581 and parameters: {'long_window': 353, 'short_window': 6}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 23:54:58,692] Trial 44 finished with value: 0.707498100686088 and parameters: {'long_window': 350, 'short_window': 8}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 23:55:00,502] Trial 45 finished with value: 0.8070470923744154 and parameters: {'long_window': 414, 'short_window': 32}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 23:55:02,352] Trial 46 finished with value: 0.7948667488080866 and parameters: {'long_window': 305, 'short_window': 143}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 23:55:04,220] Trial 47 finished with value: 0.701887789275729 and parameters: {'long_window': 220, 'short_window': 46}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 23:55:06,151] Trial 48 finished with value: 0.7485650916634171 and parameters: {'long_window': 327, 'short_window': 11}. Best is trial 31 with value: 0.8550809811155904.
# [I 2025-03-02 23:55:08,012] A new study created in memory with name: no-name-5de0a12e-5638-40df-be96-ffb8ed51c262
# [I 2025-03-02 23:55:08,008] Trial 49 finished with value: 0.8258087878717705 and parameters: {'long_window': 419, 'short_window': 27}. Best is trial 31 with value: 0.8550809811155904.
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-03-02 23:55:08,019] Trial 0 finished with value: -1.0 and parameters: {'long_window': 218, 'short_window': 240}. Best is trial 0 with value: -1.0.
# [I 2025-03-02 23:55:10,510] Trial 1 finished with value: 0.7641308974129813 and parameters: {'long_window': 380, 'short_window': 153}. Best is trial 1 with value: 0.7641308974129813.
# [I 2025-03-02 23:55:13,149] Trial 2 finished with value: 0.7654482963758183 and parameters: {'long_window': 120, 'short_window': 43}. Best is trial 2 with value: 0.7654482963758183.
# [I 2025-03-02 23:55:13,151] Trial 3 finished with value: -1.0 and parameters: {'long_window': 76, 'short_window': 219}. Best is trial 2 with value: 0.7654482963758183.
# [I 2025-03-02 23:55:15,748] Trial 4 finished with value: 0.791437253216959 and parameters: {'long_window': 321, 'short_window': 180}. Best is trial 4 with value: 0.791437253216959.
# [I 2025-03-02 23:55:15,750] Trial 5 finished with value: -1.0 and parameters: {'long_window': 59, 'short_window': 245}. Best is trial 4 with value: 0.791437253216959.
# [I 2025-03-02 23:55:18,290] Trial 6 finished with value: 0.8183918949602138 and parameters: {'long_window': 425, 'short_window': 57}. Best is trial 6 with value: 0.8183918949602138.
# [I 2025-03-02 23:55:20,873] Trial 7 finished with value: 0.5288121041983879 and parameters: {'long_window': 132, 'short_window': 50}. Best is trial 6 with value: 0.8183918949602138.
# [I 2025-03-02 23:55:23,459] Trial 8 finished with value: 0.7167525590311088 and parameters: {'long_window': 187, 'short_window': 135}. Best is trial 6 with value: 0.8183918949602138.
# [I 2025-03-02 23:55:26,016] Trial 9 finished with value: 0.7345598333401674 and parameters: {'long_window': 244, 'short_window': 77}. Best is trial 6 with value: 0.8183918949602138.
# [I 2025-03-02 23:55:28,602] Trial 10 finished with value: 0.8335336864925832 and parameters: {'long_window': 491, 'short_window': 6}. Best is trial 10 with value: 0.8335336864925832.
# [I 2025-03-02 23:55:31,080] Trial 11 finished with value: 0.7995883723193823 and parameters: {'long_window': 487, 'short_window': 6}. Best is trial 10 with value: 0.8335336864925832.
# [I 2025-03-02 23:55:33,618] Trial 12 finished with value: 0.7626883521705151 and parameters: {'long_window': 493, 'short_window': 90}. Best is trial 10 with value: 0.8335336864925832.
# [I 2025-03-02 23:55:36,118] Trial 13 finished with value: 0.8453843644962654 and parameters: {'long_window': 419, 'short_window': 8}. Best is trial 13 with value: 0.8453843644962654.
# [I 2025-03-02 23:55:38,609] Trial 14 finished with value: 0.8162673735258597 and parameters: {'long_window': 403, 'short_window': 6}. Best is trial 13 with value: 0.8453843644962654.
# [I 2025-03-02 23:55:41,135] Trial 15 finished with value: 0.8078100828527125 and parameters: {'long_window': 359, 'short_window': 100}. Best is trial 13 with value: 0.8453843644962654.
# [I 2025-03-02 23:55:43,683] Trial 16 finished with value: 0.7826813245726562 and parameters: {'long_window': 443, 'short_window': 30}. Best is trial 13 with value: 0.8453843644962654.
# [I 2025-03-02 23:55:46,368] Trial 17 finished with value: 0.8191640862327044 and parameters: {'long_window': 321, 'short_window': 107}. Best is trial 13 with value: 0.8453843644962654.
# [I 2025-03-02 23:55:48,901] Trial 18 finished with value: 0.8405759563443457 and parameters: {'long_window': 456, 'short_window': 21}. Best is trial 13 with value: 0.8453843644962654.
# [I 2025-03-02 23:55:51,934] Trial 19 finished with value: 0.7643974076060985 and parameters: {'long_window': 295, 'short_window': 76}. Best is trial 13 with value: 0.8453843644962654.
# [I 2025-03-02 23:55:54,416] Trial 20 finished with value: 0.8068729534817568 and parameters: {'long_window': 450, 'short_window': 23}. Best is trial 13 with value: 0.8453843644962654.
# [I 2025-03-02 23:55:56,882] Trial 21 finished with value: 0.8567818805779357 and parameters: {'long_window': 498, 'short_window': 21}. Best is trial 21 with value: 0.8567818805779357.
# [I 2025-03-02 23:55:59,364] Trial 22 finished with value: 0.8015588312873431 and parameters: {'long_window': 450, 'short_window': 34}. Best is trial 21 with value: 0.8567818805779357.
# [I 2025-03-02 23:56:01,885] Trial 23 finished with value: 0.8032831661859403 and parameters: {'long_window': 367, 'short_window': 61}. Best is trial 21 with value: 0.8567818805779357.
# [I 2025-03-02 23:56:04,415] Trial 24 finished with value: 0.8458196127372359 and parameters: {'long_window': 410, 'short_window': 26}. Best is trial 21 with value: 0.8567818805779357.
# [I 2025-03-02 23:56:06,918] Trial 25 finished with value: 0.7665109320196111 and parameters: {'long_window': 406, 'short_window': 122}. Best is trial 21 with value: 0.8567818805779357.
# [I 2025-03-02 23:56:09,529] Trial 26 finished with value: 0.7966460624197186 and parameters: {'long_window': 337, 'short_window': 72}. Best is trial 21 with value: 0.8567818805779357.
# [I 2025-03-02 23:56:12,127] Trial 27 finished with value: 0.8049768918705343 and parameters: {'long_window': 401, 'short_window': 40}. Best is trial 21 with value: 0.8567818805779357.
# [I 2025-03-02 23:56:14,694] Trial 28 finished with value: 0.7247794066384641 and parameters: {'long_window': 288, 'short_window': 22}. Best is trial 21 with value: 0.8567818805779357.
# [I 2025-03-02 23:56:17,369] Trial 29 finished with value: 0.7655123714817725 and parameters: {'long_window': 256, 'short_window': 209}. Best is trial 21 with value: 0.8567818805779357.
# [I 2025-03-02 23:56:19,895] Trial 30 finished with value: 0.7201498223185144 and parameters: {'long_window': 500, 'short_window': 166}. Best is trial 21 with value: 0.8567818805779357.
# [I 2025-03-02 23:56:22,329] Trial 31 finished with value: 0.7944589186359278 and parameters: {'long_window': 465, 'short_window': 22}. Best is trial 21 with value: 0.8567818805779357.
# [I 2025-03-02 23:56:24,785] Trial 32 finished with value: 0.828820868945412 and parameters: {'long_window': 429, 'short_window': 20}. Best is trial 21 with value: 0.8567818805779357.
# [I 2025-03-02 23:56:27,214] Trial 33 finished with value: 0.7874860140489806 and parameters: {'long_window': 465, 'short_window': 46}. Best is trial 21 with value: 0.8567818805779357.
# [I 2025-03-02 23:56:29,675] Trial 34 finished with value: 0.7898359442979548 and parameters: {'long_window': 380, 'short_window': 59}. Best is trial 21 with value: 0.8567818805779357.
# [I 2025-03-02 23:56:32,107] Trial 35 finished with value: 0.8397774112857213 and parameters: {'long_window': 468, 'short_window': 40}. Best is trial 21 with value: 0.8567818805779357.
# [I 2025-03-02 23:56:34,548] Trial 36 finished with value: 0.8762915718982496 and parameters: {'long_window': 422, 'short_window': 13}. Best is trial 36 with value: 0.8762915718982496.
# [I 2025-03-02 23:56:36,979] Trial 37 finished with value: 0.8433385572352649 and parameters: {'long_window': 427, 'short_window': 6}. Best is trial 36 with value: 0.8762915718982496.
# [I 2025-03-02 23:56:39,437] Trial 38 finished with value: 0.8261289037680539 and parameters: {'long_window': 355, 'short_window': 33}. Best is trial 36 with value: 0.8762915718982496.
# [I 2025-03-02 23:56:41,896] Trial 39 finished with value: 0.7561443748065338 and parameters: {'long_window': 394, 'short_window': 191}. Best is trial 36 with value: 0.8762915718982496.
# [I 2025-03-02 23:56:44,385] Trial 40 finished with value: 0.7867620267744608 and parameters: {'long_window': 190, 'short_window': 52}. Best is trial 36 with value: 0.8762915718982496.
# [I 2025-03-02 23:56:46,817] Trial 41 finished with value: 0.833688969288206 and parameters: {'long_window': 418, 'short_window': 5}. Best is trial 36 with value: 0.8762915718982496.
# [I 2025-03-02 23:56:49,268] Trial 42 finished with value: 0.8330586830372158 and parameters: {'long_window': 428, 'short_window': 16}. Best is trial 36 with value: 0.8762915718982496.
# [I 2025-03-02 23:56:51,709] Trial 43 finished with value: 0.7772013711620219 and parameters: {'long_window': 391, 'short_window': 14}. Best is trial 36 with value: 0.8762915718982496.
# [I 2025-03-02 23:56:54,134] Trial 44 finished with value: 0.8501178752472694 and parameters: {'long_window': 479, 'short_window': 30}. Best is trial 36 with value: 0.8762915718982496.
# [I 2025-03-02 23:56:56,559] Trial 45 finished with value: 0.7865333723010339 and parameters: {'long_window': 486, 'short_window': 34}. Best is trial 36 with value: 0.8762915718982496.
# [I 2025-03-02 23:56:59,009] Trial 46 finished with value: 0.8280824363871909 and parameters: {'long_window': 473, 'short_window': 68}. Best is trial 36 with value: 0.8762915718982496.
# [I 2025-03-02 23:57:01,447] Trial 47 finished with value: 0.8377939077006331 and parameters: {'long_window': 434, 'short_window': 45}. Best is trial 36 with value: 0.8762915718982496.
# [I 2025-03-02 23:57:03,947] Trial 48 finished with value: 0.6366566676059222 and parameters: {'long_window': 103, 'short_window': 91}. Best is trial 36 with value: 0.8762915718982496.
# [I 2025-03-02 23:57:06,386] A new study created in memory with name: no-name-59db1376-bfa3-435f-9b8a-600fb2d48325
# [I 2025-03-02 23:57:06,382] Trial 49 finished with value: 0.7374388933835474 and parameters: {'long_window': 482, 'short_window': 148}. Best is trial 36 with value: 0.8762915718982496.
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-03-02 23:57:06,394] Trial 0 finished with value: -1.0 and parameters: {'long_window': 218, 'short_window': 240}. Best is trial 0 with value: -1.0.
# [I 2025-03-02 23:57:09,513] Trial 1 finished with value: 0.7108622630623633 and parameters: {'long_window': 380, 'short_window': 153}. Best is trial 1 with value: 0.7108622630623633.
# [I 2025-03-02 23:57:12,651] Trial 2 finished with value: 0.7063823687017756 and parameters: {'long_window': 120, 'short_window': 43}. Best is trial 1 with value: 0.7108622630623633.
# [I 2025-03-02 23:57:12,653] Trial 3 finished with value: -1.0 and parameters: {'long_window': 76, 'short_window': 219}. Best is trial 1 with value: 0.7108622630623633.
# [I 2025-03-02 23:57:15,745] Trial 4 finished with value: 0.7542648805807726 and parameters: {'long_window': 321, 'short_window': 180}. Best is trial 4 with value: 0.7542648805807726.
# [I 2025-03-02 23:57:15,747] Trial 5 finished with value: -1.0 and parameters: {'long_window': 59, 'short_window': 245}. Best is trial 4 with value: 0.7542648805807726.
# [I 2025-03-02 23:57:18,818] Trial 6 finished with value: 0.7386383028072222 and parameters: {'long_window': 425, 'short_window': 57}. Best is trial 4 with value: 0.7542648805807726.
# [I 2025-03-02 23:57:21,943] Trial 7 finished with value: 0.5064203922758194 and parameters: {'long_window': 132, 'short_window': 50}. Best is trial 4 with value: 0.7542648805807726.
# [I 2025-03-02 23:57:25,058] Trial 8 finished with value: 0.7124931697072219 and parameters: {'long_window': 187, 'short_window': 135}. Best is trial 4 with value: 0.7542648805807726.
# [I 2025-03-02 23:57:28,151] Trial 9 finished with value: 0.6993555560292417 and parameters: {'long_window': 244, 'short_window': 77}. Best is trial 4 with value: 0.7542648805807726.
# [I 2025-03-02 23:57:31,257] Trial 10 finished with value: 0.7504601988998055 and parameters: {'long_window': 335, 'short_window': 183}. Best is trial 4 with value: 0.7542648805807726.
# [I 2025-03-02 23:57:34,360] Trial 11 finished with value: 0.763915807087122 and parameters: {'long_window': 317, 'short_window': 183}. Best is trial 11 with value: 0.763915807087122.
# [I 2025-03-02 23:57:37,956] Trial 12 finished with value: 0.7614221653176988 and parameters: {'long_window': 312, 'short_window': 186}. Best is trial 11 with value: 0.763915807087122.
# [I 2025-03-02 23:57:41,037] Trial 13 finished with value: 0.7509954278736147 and parameters: {'long_window': 469, 'short_window': 102}. Best is trial 11 with value: 0.763915807087122.
# [I 2025-03-02 23:57:44,136] Trial 14 finished with value: 0.7687082570683635 and parameters: {'long_window': 296, 'short_window': 8}. Best is trial 14 with value: 0.7687082570683635.
# [I 2025-03-02 23:57:47,250] Trial 15 finished with value: 0.7586538712674784 and parameters: {'long_window': 277, 'short_window': 9}. Best is trial 14 with value: 0.7687082570683635.
# [I 2025-03-02 23:57:50,334] Trial 16 finished with value: 0.7664409533831082 and parameters: {'long_window': 397, 'short_window': 112}. Best is trial 14 with value: 0.7687082570683635.
# [I 2025-03-02 23:57:53,396] Trial 17 finished with value: 0.7384491460313415 and parameters: {'long_window': 488, 'short_window': 15}. Best is trial 14 with value: 0.7687082570683635.
# [I 2025-03-02 23:57:56,481] Trial 18 finished with value: 0.7652972731738975 and parameters: {'long_window': 397, 'short_window': 108}. Best is trial 14 with value: 0.7687082570683635.
# [I 2025-03-02 23:57:59,558] Trial 19 finished with value: 0.7786285288580824 and parameters: {'long_window': 420, 'short_window': 91}. Best is trial 19 with value: 0.7786285288580824.
# [I 2025-03-02 23:58:02,647] Trial 20 finished with value: 0.7518748294160366 and parameters: {'long_window': 451, 'short_window': 80}. Best is trial 19 with value: 0.7786285288580824.
# [I 2025-03-02 23:58:05,737] Trial 21 finished with value: 0.7622590196974133 and parameters: {'long_window': 380, 'short_window': 118}. Best is trial 19 with value: 0.7786285288580824.
# [I 2025-03-02 23:58:08,818] Trial 22 finished with value: 0.7915042742803111 and parameters: {'long_window': 418, 'short_window': 84}. Best is trial 22 with value: 0.7915042742803111.
# [I 2025-03-02 23:58:11,897] Trial 23 finished with value: 0.7266901898672324 and parameters: {'long_window': 436, 'short_window': 30}. Best is trial 22 with value: 0.7915042742803111.
# [I 2025-03-02 23:58:14,959] Trial 24 finished with value: 0.7587216499316648 and parameters: {'long_window': 493, 'short_window': 86}. Best is trial 22 with value: 0.7915042742803111.
# [I 2025-03-02 23:58:18,062] Trial 25 finished with value: 0.7706925095069701 and parameters: {'long_window': 355, 'short_window': 66}. Best is trial 22 with value: 0.7915042742803111.
# [I 2025-03-02 23:58:21,158] Trial 26 finished with value: 0.7728552838895223 and parameters: {'long_window': 369, 'short_window': 67}. Best is trial 22 with value: 0.7915042742803111.
# [I 2025-03-02 23:58:24,242] Trial 27 finished with value: 0.7680726984748103 and parameters: {'long_window': 416, 'short_window': 90}. Best is trial 22 with value: 0.7915042742803111.
# [I 2025-03-02 23:58:27,332] Trial 28 finished with value: 0.7675137195988798 and parameters: {'long_window': 361, 'short_window': 130}. Best is trial 22 with value: 0.7915042742803111.
# [I 2025-03-02 23:58:30,423] Trial 29 finished with value: 0.7358392784331557 and parameters: {'long_window': 459, 'short_window': 150}. Best is trial 22 with value: 0.7915042742803111.
# [I 2025-03-02 23:58:33,550] Trial 30 finished with value: 0.7025606650135341 and parameters: {'long_window': 238, 'short_window': 30}. Best is trial 22 with value: 0.7915042742803111.
# [I 2025-03-02 23:58:36,642] Trial 31 finished with value: 0.7363443832244698 and parameters: {'long_window': 358, 'short_window': 59}. Best is trial 22 with value: 0.7915042742803111.
# [I 2025-03-02 23:58:39,741] Trial 32 finished with value: 0.783251545479618 and parameters: {'long_window': 356, 'short_window': 69}. Best is trial 22 with value: 0.7915042742803111.
# [I 2025-03-02 23:58:42,819] Trial 33 finished with value: 0.7784538014916835 and parameters: {'long_window': 404, 'short_window': 70}. Best is trial 22 with value: 0.7915042742803111.
# [I 2025-03-02 23:58:45,899] Trial 34 finished with value: 0.760429230995971 and parameters: {'long_window': 423, 'short_window': 93}. Best is trial 22 with value: 0.7915042742803111.
# [I 2025-03-02 23:58:48,994] Trial 35 finished with value: 0.7489121822754762 and parameters: {'long_window': 397, 'short_window': 34}. Best is trial 22 with value: 0.7915042742803111.
# [I 2025-03-02 23:58:52,071] Trial 36 finished with value: 0.7334811170388355 and parameters: {'long_window': 446, 'short_window': 46}. Best is trial 22 with value: 0.7915042742803111.
# [I 2025-03-02 23:58:55,165] Trial 37 finished with value: 0.7644483196430264 and parameters: {'long_window': 340, 'short_window': 73}. Best is trial 22 with value: 0.7915042742803111.
# [I 2025-03-02 23:58:58,271] Trial 38 finished with value: 0.7599452787533529 and parameters: {'long_window': 401, 'short_window': 95}. Best is trial 22 with value: 0.7915042742803111.
# [I 2025-03-02 23:59:01,341] Trial 39 finished with value: 0.7226798699000468 and parameters: {'long_window': 482, 'short_window': 151}. Best is trial 22 with value: 0.7915042742803111.
# [I 2025-03-02 23:59:04,475] Trial 40 finished with value: 0.6457922365847256 and parameters: {'long_window': 189, 'short_window': 118}. Best is trial 22 with value: 0.7915042742803111.
# [I 2025-03-02 23:59:07,559] Trial 41 finished with value: 0.8105518579759878 and parameters: {'long_window': 372, 'short_window': 69}. Best is trial 41 with value: 0.8105518579759878.
# [I 2025-03-02 23:59:10,634] Trial 42 finished with value: 0.7347420430114996 and parameters: {'long_window': 379, 'short_window': 54}. Best is trial 41 with value: 0.8105518579759878.
# [I 2025-03-02 23:59:13,714] Trial 43 finished with value: 0.7690091682539917 and parameters: {'long_window': 415, 'short_window': 74}. Best is trial 41 with value: 0.8105518579759878.
# [I 2025-03-02 23:59:16,792] Trial 44 finished with value: 0.6960131961510772 and parameters: {'long_window': 341, 'short_window': 42}. Best is trial 41 with value: 0.8105518579759878.
# [I 2025-03-02 23:59:20,381] Trial 45 finished with value: 0.7502974743330147 and parameters: {'long_window': 275, 'short_window': 100}. Best is trial 41 with value: 0.8105518579759878.
# [I 2025-03-02 23:59:23,455] Trial 46 finished with value: 0.803356037732167 and parameters: {'long_window': 435, 'short_window': 62}. Best is trial 41 with value: 0.8105518579759878.
# [I 2025-03-02 23:59:26,541] Trial 47 finished with value: 0.6823295892316621 and parameters: {'long_window': 433, 'short_window': 228}. Best is trial 41 with value: 0.8105518579759878.
# [I 2025-03-02 23:59:29,675] Trial 48 finished with value: 0.6234827529879214 and parameters: {'long_window': 103, 'short_window': 59}. Best is trial 41 with value: 0.8105518579759878.
# [I 2025-03-02 23:59:32,771] A new study created in memory with name: no-name-90e2e1c0-51e6-4ca6-a088-37855911da6b
# [I 2025-03-02 23:59:32,751] Trial 49 finished with value: 0.7477142778041785 and parameters: {'long_window': 469, 'short_window': 81}. Best is trial 41 with value: 0.8105518579759878.
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-03-02 23:59:32,779] Trial 0 finished with value: -1.0 and parameters: {'long_window': 218, 'short_window': 240}. Best is trial 0 with value: -1.0.
# [I 2025-03-02 23:59:33,036] Trial 1 finished with value: 2.7336286095421674 and parameters: {'long_window': 380, 'short_window': 153}. Best is trial 1 with value: 2.7336286095421674.
# [I 2025-03-02 23:59:33,366] Trial 2 finished with value: 1.4390907690281525 and parameters: {'long_window': 120, 'short_window': 43}. Best is trial 1 with value: 2.7336286095421674.
# [I 2025-03-02 23:59:33,367] Trial 3 finished with value: -1.0 and parameters: {'long_window': 76, 'short_window': 219}. Best is trial 1 with value: 2.7336286095421674.
# [I 2025-03-02 23:59:33,632] Trial 4 finished with value: 2.3739821355746957 and parameters: {'long_window': 321, 'short_window': 180}. Best is trial 1 with value: 2.7336286095421674.
# [I 2025-03-02 23:59:33,634] Trial 5 finished with value: -1.0 and parameters: {'long_window': 59, 'short_window': 245}. Best is trial 1 with value: 2.7336286095421674.
# [I 2025-03-02 23:59:33,873] Trial 6 finished with value: 3.3366618717717254 and parameters: {'long_window': 425, 'short_window': 57}. Best is trial 6 with value: 3.3366618717717254.
# [I 2025-03-02 23:59:34,193] Trial 7 finished with value: 1.3025696956020607 and parameters: {'long_window': 132, 'short_window': 50}. Best is trial 6 with value: 3.3366618717717254.
# ...
# [I 2025-03-03 00:12:40,158] Trial 27 finished with value: 0.752842895963603 and parameters: {'long_window': 404, 'short_window': 103}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-03 00:12:43,668] Trial 28 finished with value: 0.7147522890386014 and parameters: {'long_window': 309, 'short_window': 163}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-03 00:12:43,683] Trial 29 finished with value: -1.0 and parameters: {'long_window': 158, 'short_window': 230}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-03 00:12:47,186] Trial 30 finished with value: 0.7299679087980414 and parameters: {'long_window': 236, 'short_window': 208}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-03 00:12:50,679] Trial 31 finished with value: 0.7387068583151506 and parameters: {'long_window': 402, 'short_window': 91}. Best is trial 11 with value: 0.7590493638136194.
# [I 2025-03-03 00:12:54,152] Trial 32 finished with value: 0.7725293794014212 and parameters: {'long_window': 356, 'short_window': 122}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-03 00:12:57,741] Trial 33 finished with value: 0.7252561363214008 and parameters: {'long_window': 344, 'short_window': 151}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-03 00:13:01,234] Trial 34 finished with value: 0.714033939386895 and parameters: {'long_window': 268, 'short_window': 137}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-03 00:13:04,748] Trial 35 finished with value: 0.6950911802068954 and parameters: {'long_window': 369, 'short_window': 120}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-03 00:13:08,255] Trial 36 finished with value: 0.7586304129009177 and parameters: {'long_window': 322, 'short_window': 178}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-03 00:13:11,738] Trial 37 finished with value: 0.7677112929466264 and parameters: {'long_window': 327, 'short_window': 192}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-03 00:13:15,732] Trial 38 finished with value: 0.7057810321278077 and parameters: {'long_window': 349, 'short_window': 248}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-03 00:13:19,211] Trial 39 finished with value: 0.7190263446339167 and parameters: {'long_window': 395, 'short_window': 231}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-03 00:13:22,706] Trial 40 finished with value: 0.7285565182414229 and parameters: {'long_window': 420, 'short_window': 209}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-03 00:13:26,417] Trial 41 finished with value: 0.7632069421328008 and parameters: {'long_window': 325, 'short_window': 186}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-03 00:13:29,908] Trial 42 finished with value: 0.7279692179185736 and parameters: {'long_window': 360, 'short_window': 172}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-03 00:13:33,308] Trial 43 finished with value: 0.7360055149852819 and parameters: {'long_window': 317, 'short_window': 191}. Best is trial 32 with value: 0.7725293794014212.
# [I 2025-03-03 00:13:36,675] Trial 44 finished with value: 0.777632463725657 and parameters: {'long_window': 331, 'short_window': 201}. Best is trial 44 with value: 0.777632463725657.
# [I 2025-03-03 00:13:40,070] Trial 45 finished with value: 0.7612774583917752 and parameters: {'long_window': 326, 'short_window': 203}. Best is trial 44 with value: 0.777632463725657.
# [I 2025-03-03 00:13:43,439] Trial 46 finished with value: 0.7037871317791564 and parameters: {'long_window': 444, 'short_window': 216}. Best is trial 44 with value: 0.777632463725657.
# [I 2025-03-03 00:13:46,800] Trial 47 finished with value: 0.696022840992405 and parameters: {'long_window': 388, 'short_window': 236}. Best is trial 44 with value: 0.777632463725657.
# [I 2025-03-03 00:13:50,181] Trial 48 finished with value: 0.7159253275815567 and parameters: {'long_window': 337, 'short_window': 197}. Best is trial 44 with value: 0.777632463725657.
# [I 2025-03-03 00:13:53,547] A new study created in memory with name: no-name-315758cf-de15-49b6-be24-d78520bb35ed
# [I 2025-03-03 00:13:53,540] Trial 49 finished with value: 0.6254677461313783 and parameters: {'long_window': 293, 'short_window': 61}. Best is trial 44 with value: 0.777632463725657.
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-03-03 00:13:53,555] Trial 0 finished with value: -1.0 and parameters: {'long_window': 218, 'short_window': 240}. Best is trial 0 with value: -1.0.
# [I 2025-03-03 00:13:53,648] Trial 1 finished with value: 4.026176331580236 and parameters: {'long_window': 380, 'short_window': 153}. Best is trial 1 with value: 4.026176331580236.
# [I 2025-03-03 00:13:53,809] Trial 2 finished with value: 0.14106125947219075 and parameters: {'long_window': 120, 'short_window': 43}. Best is trial 1 with value: 4.026176331580236.
# [I 2025-03-03 00:13:53,810] Trial 3 finished with value: -1.0 and parameters: {'long_window': 76, 'short_window': 219}. Best is trial 1 with value: 4.026176331580236.
# [I 2025-03-03 00:13:53,920] Trial 4 finished with value: 2.435561637548207 and parameters: {'long_window': 321, 'short_window': 180}. Best is trial 1 with value: 4.026176331580236.
# [I 2025-03-03 00:13:53,921] Trial 5 finished with value: -1.0 and parameters: {'long_window': 59, 'short_window': 245}. Best is trial 1 with value: 4.026176331580236.
# [W 2025-03-03 00:13:53,980] Trial 6 failed with parameters: {'long_window': 425, 'short_window': 57} because of the following error: IndexError('array assignment index out of range').
# Traceback (most recent call last):
#   File "c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\optuna\study\_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\alexr\AppData\Local\Temp\ipykernel_4264\1435164017.py", line 18, in objective
#     results = bt.backtest()
#               ^^^^^^^^^^^^^
#   File "c:\Users\alexr\AlgoTester\utils\backtester.py", line 54, in backtest
#     self.results = self.cerebro.run()
#                    ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\backtrader\cerebro.py", line 1132, in run
#     runstrat = self.runstrategies(iterstrat)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\backtrader\cerebro.py", line 1298, in runstrategies
#     self._runonce(runstrats)
#   File "c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\backtrader\cerebro.py", line 1657, in _runonce
#     strat._once()
#   File "c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\backtrader\lineiterator.py", line 297, in _once
#     indicator._once()
#   File "c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\backtrader\lineiterator.py", line 297, in _once
#     indicator._once()
#   File "c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\backtrader\lineiterator.py", line 317, in _once
#     self.oncestart(self._minperiod - 1, self._minperiod)
#   File "c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\backtrader\lineiterator.py", line 327, in oncestart
#     self.once(start, end)
#   File "c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\backtrader\indicators\basicops.py", line 364, in once
#     dst[i] = math.fsum(src[i - period + 1:i + 1]) / period
#     ~~~^^^
# IndexError: array assignment index out of range
# [W 2025-03-03 00:13:53,982] Trial 6 failed with value None.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[39], line 33
#      30 df_data = price_data[ticker]
#      32 for i in [5, 10, 20]:
# ---> 33     df, param_pairs = find_parameters(ticker, df_data, n_splits=i, n_trials=50)
#      35     # plt.plot(df.index, df['short_window'], label='Short Window')
#      36     # plt.plot(df.index, df['long_window'], label='Long Window')
#      37     # plt.title(f'{ticker} - {i} Splits')
#      38     # plt.xlabel('Date')
#      39     # plt.ylabel('Window Size')
#      40     # plt.legend()
#      42     long_windows = [f['long_window'] for f in param_pairs]
#
# Cell In[39], line 20, in find_parameters(ticker, df, n_splits, n_trials, verbose)
#      17 test = df.iloc[test_index]
#      19 # Fit the model on the training set
# ---> 20 best_params = optimize_params(ticker, train, n_trials)
#      22 df_output.loc[df_output.index.isin(train.index), 'short_window'] = best_params['short_window']
#      23 df_output.loc[df_output.index.isin(train.index), 'long_window'] = best_params['long_window']
#
# Cell In[24], line 23, in optimize_params(ticker, df, n_trials)
#      20     return results['sharpe']
#      22 study = optuna.create_study(direction="maximize", sampler=TPESampler(seed=42))
# ---> 23 study.optimize(objective, n_trials=n_trials, show_progress_bar=True)
#      25 return study.best_params
#
# File c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\optuna\study\study.py:442, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     339 def optimize(
#     340     self,
#     341     func: ObjectiveFuncType,
#    (...)
#     348     show_progress_bar: bool = False,
#     349 ) -> None:
#     350     """Optimize an objective function.
#     351
#     352     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     440             If nested invocation of this method occurs.
#     441     """
# --> 442     _optimize(
#     443         study=self,
#     444         func=func,
#     445         n_trials=n_trials,
#     446         timeout=timeout,
#     447         n_jobs=n_jobs,
#     448         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     449         callbacks=callbacks,
#     450         gc_after_trial=gc_after_trial,
#     451         show_progress_bar=show_progress_bar,
#     452     )
#
# File c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\optuna\study\_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\optuna\study\_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\optuna\study\_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\optuna\study\_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# Cell In[24], line 18, in optimize_params.<locals>.objective(trial)
#      16 bt = BackTester(pda)
#      17 bt.add_strategy(MovingAverageCrossoverStrategy, tickers=tl, price_data=pda, short_window=short_window, long_window=long_window, rebalance_period=21)
# ---> 18 results = bt.backtest()
#      20 return results['sharpe']
#
# File c:\Users\alexr\AlgoTester\utils\backtester.py:54, in BackTester.backtest(self)
#      52 def backtest(self) -> dict:
#      53     """Run backtest and return performance metrics"""
# ---> 54     self.results = self.cerebro.run()
#      55     self.portfolio_tracker = pd.DataFrame(self.results[0].portfolio_tracker)
#      56     self.portfolio_tracker.set_index('date', inplace=True)
#
# File c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\backtrader\cerebro.py:1132, in Cerebro.run(self, **kwargs)
#    1128 if not self._dooptimize or self.p.maxcpus == 1:
#    1129     # If no optimmization is wished ... or 1 core is to be used
#    1130     # let's skip process "spawning"
#    1131     for iterstrat in iterstrats:
# -> 1132         runstrat = self.runstrategies(iterstrat)
#    1133         self.runstrats.append(runstrat)
#    1134         if self._dooptimize:
#
# File c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\backtrader\cerebro.py:1298, in Cerebro.runstrategies(self, iterstrat, predata)
#    1296         self._runonce_old(runstrats)
#    1297     else:
# -> 1298         self._runonce(runstrats)
#    1299 else:
#    1300     if self.p.oldsync:
#
# File c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\backtrader\cerebro.py:1657, in Cerebro._runonce(self, runstrats)
#    1650 '''
#    1651 Actual implementation of run in vector mode.
#    1652
#    1653 Strategies are still invoked on a pseudo-event mode in which ``next``
#    1654 is called for each data arrival
#    1655 '''
#    1656 for strat in runstrats:
# -> 1657     strat._once()
#    1658     strat.reset()  # strat called next by next - reset lines
#    1660 # The default once for strategies does nothing and therefore
#    1661 # has not moved forward all datas/indicators/observers that
#    1662 # were homed before calling once, Hence no "need" to do it
#    1663 # here again, because pointers are at 0
#
# File c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\backtrader\lineiterator.py:297, in LineIterator._once(self)
#     294 self.forward(size=self._clock.buflen())
#     296 for indicator in self._lineiterators[LineIterator.IndType]:
# --> 297     indicator._once()
#     299 for observer in self._lineiterators[LineIterator.ObsType]:
#     300     observer.forward(size=self.buflen())
#
# File c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\backtrader\lineiterator.py:297, in LineIterator._once(self)
#     294 self.forward(size=self._clock.buflen())
#     296 for indicator in self._lineiterators[LineIterator.IndType]:
# --> 297     indicator._once()
#     299 for observer in self._lineiterators[LineIterator.ObsType]:
#     300     observer.forward(size=self.buflen())
#
# File c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\backtrader\lineiterator.py:317, in LineIterator._once(self)
#     313 # These 3 remain empty for a strategy and therefore play no role
#     314 # because a strategy will always be executed on a next basis
#     315 # indicators are each called with its min period
#     316 self.preonce(0, self._minperiod - 1)
# --> 317 self.oncestart(self._minperiod - 1, self._minperiod)
#     318 self.once(self._minperiod, self.buflen())
#     320 for line in self.lines:
#
# File c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\backtrader\lineiterator.py:327, in LineIterator.oncestart(self, start, end)
#     326 def oncestart(self, start, end):
# --> 327     self.once(start, end)
#
# File c:\Users\alexr\miniconda3\envs\ai\Lib\site-packages\backtrader\indicators\basicops.py:364, in Average.once(self, start, end)
#     361 period = self.p.period
#     363 for i in range(start, end):
# --> 364     dst[i] = math.fsum(src[i - period + 1:i + 1]) / period
#
# IndexError: array assignment index out of range

# %% [markdown]
# # END
